# %%
#load model

import tensorflow as tf
import numpy as np
import itertools
from transformers import TFAutoModelForMaskedLM, AutoTokenizer

model_name = "HooshvareLab/bert-base-parsbert-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = TFAutoModelForMaskedLM.from_pretrained(model_name, output_hidden_states=False, output_attentions=False)
# Out:
# All model checkpoint layers were used when initializing TFBertForMaskedLM.
#
# All the layers of TFBertForMaskedLM were initialized from the model checkpoint at HooshvareLab/bert-base-parsbert-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForMaskedLM for predictions without further training.

# %%
def calculate_sentence_score(sentence_tokens,k=1000,epsilon=0.000001):
    sentence_score = 1000000000000
    sentence = ' '.join(sentence_tokens)
    # inputs = tokenizer(sentence, return_tensors="tf")
    # input_ids = inputs["input_ids"]
    for i,token in enumerate(sentence_tokens):
    # for i in range(len(input_ids)):
        found = False
        # token =  tokenizer.convert_ids_to_tokens([input_ids[i]])
        # token = sentence_tokens[i]
        # masked_input_ids = tf.tensor_scatter_nd_update(input_ids, [[0, i]], [tokenizer.mask_token_id])
        masked_text = ' '.join(sentence_tokens[:i])+' [MASK] '+' '.join(sentence_tokens[i+1:])

        
        input_ids = tokenizer.encode(masked_text, return_tensors="tf")

        outputs = model(input_ids)
        print(outputs[-1])
        logits = outputs.logits
        # logits = model.__call__(input_ids)[0]
        mask_token_index = tf.where(input_ids == tokenizer.mask_token_id)[0, 1]
        mask_token_logits = logits[0, mask_token_index, :]
        top_k_values, top_k_indices = tf.math.top_k(mask_token_logits, k=k)
        predicted_token_indices = top_k_indices.numpy()
        probabilities = tf.nn.softmax(top_k_values).numpy()
        predicted_tokens = tokenizer.convert_ids_to_tokens(predicted_token_indices)
        for j,predicted_token in enumerate(predicted_tokens):
            if predicted_token == token:
                sentence_score *= probabilities[j]
                found = True
                break
        if not found:
            sentence_score *= epsilon
        # print(token)
        # for i in range(k):
        #     print(predicted_tokens[i],probabilities[i])
        # print('----')
    return sentence_score

# %%
def clean_permutations(permutations):
    return permutations

# %%
import time
def find_ordered_sentence(sentence):
    tokens = tokenizer.tokenize(sentence)
    permutations = list(itertools.permutations(tokens))
    cleaned_permutations = clean_permutations(permutations)
    scores = []
    for i,permutation in enumerate(cleaned_permutations):
        permutation_sentence = ' '.join(permutation)
        score = calculate_sentence_score(list(permutation))
        print(permutation_sentence)
        print(score)
        scores.append((permutation_sentence,score))
        print(i+1,'/',len(permutations))
    scores.sort(key=lambda x: x[1], reverse=True)
    for score in scores:
        print(score)
    return scores[0][1]

# %%
#main code
find_ordered_sentence('شد خانه خراب')
# Out:
# tf.Tensor(
# [[[-8.249292  -7.8504586 -4.190132  ... -6.3265657 -5.8598886 -5.0887065]
#   [-7.5560904 -7.310338  -5.4801974 ... -7.349765  -7.0495486 -4.5247097]
#   [-8.363945  -8.286933  -7.5320415 ... -8.101752  -6.7629743 -6.6129885]
#   [-7.0748463 -6.1730356 -5.0125318 ... -7.770436  -1.3121433 -3.093759 ]
#   [-5.3221436 -5.760626  -7.0017366 ... -4.122114  -2.3114796 -2.572641 ]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[ -9.703397   -9.22757    -6.2324033 ...  -7.6335425  -8.297429
#     -7.1577544]
#   [-10.257478   -9.560696   -7.015505  ...  -9.4152355  -9.79613
#     -6.700428 ]
#   [ -6.2258716  -4.940087   -8.36199   ...  -4.187895   -4.8127046
#     -3.8332863]
#   [ -9.152376   -8.387696   -7.1129246 ...  -8.585529   -6.101666
#     -6.8454194]
#   [ -6.6361995  -7.9997687  -7.9749117 ...  -6.400436   -5.4669805
#     -4.5484853]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-9.148305  -8.682382  -4.4242907 ... -7.0923715 -7.090711  -7.1360064]
#   [-8.426776  -8.802432  -6.631665  ... -8.176101  -7.8416896 -4.9117794]
#   [-5.970503  -4.9856644 -5.9513702 ... -4.040084  -4.4581203 -3.9757113]
#   [-6.689412  -5.68898   -5.8128033 ... -5.2503505 -2.8454492 -5.129885 ]
#   [-6.3259325 -7.2348175 -7.2955084 ... -4.256025  -5.060711  -3.952661 ]]], shape=(1, 5, 100000), dtype=float32)
# شد خانه خراب
# 8.8324934161472
# 1 / 6
# tf.Tensor(
# [[[-8.993559  -8.615107  -5.248762  ... -6.7510524 -6.675881  -5.968898 ]
#   [-6.9428325 -6.375573  -6.342052  ... -5.297788  -5.202129  -4.205629 ]
#   [-7.8151064 -8.766344  -6.6004634 ... -9.087789  -5.109783  -4.221164 ]
#   [-7.4943495 -6.160631  -6.088037  ... -5.412234  -4.274767  -4.988662 ]
#   [-5.35152   -6.2389183 -6.898877  ... -4.6477513 -2.681828  -2.4454546]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-10.222246   -9.685112   -4.9012604 ...  -7.6407967  -8.55655
#     -8.731068 ]
#   [ -9.879557   -9.039812   -6.056163  ...  -8.351079   -9.026442
#     -7.715059 ]
#   [ -7.316955   -6.955429   -6.5506706 ...  -6.321088   -5.919043
#     -5.8488503]
#   [ -8.703228   -7.4427996  -6.149811  ...  -5.509251   -6.864231
#     -7.2875013]
#   [ -6.370008   -8.178084   -7.3321595 ...  -4.8309007  -5.7480564
#     -4.2264924]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-9.224104  -8.761701  -6.7185917 ... -7.122593  -6.9031243 -5.7321863]
#   [-9.294455  -8.355037  -8.133247  ... -7.9872723 -7.547727  -4.803856 ]
#   [-5.498947  -5.011219  -7.1903954 ... -6.235543  -2.4239373 -1.2548745]
#   [-8.431015  -7.469058  -7.318343  ... -6.620568  -5.3747697 -5.5852714]
#   [-7.548358  -7.809999  -8.547222  ... -6.888465  -4.7593017 -4.172517 ]]], shape=(1, 5, 100000), dtype=float32)
# شد خراب خانه
# 0.009321286702119572
# 2 / 6
# tf.Tensor(
# [[[-9.378526  -8.948566  -6.0342226 ... -7.3995733 -7.7467074 -7.66397  ]
#   [-9.4840355 -8.724686  -8.134096  ... -6.509694  -7.2596316 -6.8777885]
#   [-8.727013  -8.604795  -8.816383  ... -8.806061  -7.623793  -5.318176 ]
#   [-7.985568  -6.847248  -6.951945  ... -7.003003  -4.91581   -6.0843763]
#   [-6.1340675 -7.6686506 -8.295362  ... -6.046313  -4.9225955 -4.490793 ]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-7.336851  -7.2458477 -4.0185623 ... -5.6928134 -5.183496  -4.2780795]
#   [-7.2815194 -7.1925    -3.5411255 ... -6.1999    -6.2259855 -4.397712 ]
#   [-3.705203  -3.14399   -7.012332  ... -3.3185477 -1.8812828 -1.6406996]
#   [-8.555405  -7.698982  -5.627849  ... -8.690917  -4.220253  -5.783885 ]
#   [-4.4990053 -5.834818  -6.2689824 ... -3.480368  -2.414391  -2.187856 ]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-7.4857225 -7.537043  -3.9385467 ... -5.6632223 -6.1026263 -5.852463 ]
#   [-7.190296  -6.718171  -6.5147533 ... -5.072872  -6.0672746 -4.3891134]
#   [-4.1954527 -4.038656  -8.370928  ... -4.4759846 -2.0951662 -1.4606621]
#   [-7.241026  -6.4240923 -5.9358616 ... -5.3745146 -5.0210137 -6.380622 ]
#   [-5.8627977 -8.19878   -7.163889  ... -4.5668797 -5.0600286 -3.5993829]]], shape=(1, 5, 100000), dtype=float32)
# خانه شد خراب
# 2.714899675500319
# 3 / 6
# tf.Tensor(
# [[[-8.022385  -8.219339  -4.929986  ... -6.345813  -6.225119  -5.2963047]
#   [-5.304982  -4.9950724 -6.861987  ... -3.1391904 -3.6785843 -2.9214203]
#   [-6.6511135 -7.129095  -6.7558165 ... -7.9587483 -2.9346447 -2.5244274]
#   [-9.389828  -8.7497225 -6.767006  ... -9.094256  -5.772953  -4.9296637]
#   [-5.1982746 -6.119075  -7.752974  ... -5.795242  -2.7642941 -2.40318  ]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-7.3639383 -7.2577505 -3.0272694 ... -5.0439763 -5.033368  -6.0699997]
#   [-5.0735765 -4.549587  -6.09569   ... -3.146171  -4.333404  -3.4318967]
#   [-5.2514253 -5.6889815 -6.767267  ... -3.4462867 -1.4716327 -1.7314224]
#   [-8.488956  -7.965433  -6.721879  ... -8.375457  -5.758881  -6.343938 ]
#   [-3.792732  -6.367285  -6.649783  ... -3.4024322 -3.1670687 -1.4092648]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-6.6257353  -6.585618   -3.8185163  ... -5.0165744  -4.6460567
#    -3.6043372 ]
#   [-6.417943   -6.218033   -5.115409   ... -5.2171803  -5.3465943
#    -4.5537496 ]
#   [-4.166559   -4.6427283  -6.0653915  ... -6.0104165   0.7314103
#    -0.14487094]
#   [-7.04295    -5.5878425  -5.974744   ... -5.407697   -3.4356883
#    -4.866964  ]
#   [-5.6950336  -6.0161667  -6.6330767  ... -4.323584   -2.0676649
#    -2.5197625 ]]], shape=(1, 5, 100000), dtype=float32)
# خانه خراب شد
# 2104356.07099184
# 4 / 6
# tf.Tensor(
# [[[-8.287369  -8.156331  -3.5279932 ... -6.0161853 -5.8471065 -7.913864 ]
#   [-8.055047  -7.9754643 -6.146898  ... -5.5319133 -5.4404593 -5.980112 ]
#   [-7.8156986 -8.181131  -5.8815427 ... -8.431127  -7.147305  -6.8963456]
#   [-7.26019   -5.7787566 -5.820615  ... -4.0814133 -5.0354514 -6.4883947]
#   [-5.3495617 -7.9573755 -7.4214497 ... -4.684133  -4.960446  -3.6857686]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-8.559946  -7.9251432 -5.0921726 ... -5.818752  -5.903891  -5.274082 ]
#   [-7.2617035 -6.490382  -5.1805773 ... -6.9088235 -3.800579  -2.2442713]
#   [-5.3000135 -5.0446014 -6.7637997 ... -3.3402638 -3.9606109 -2.7042432]
#   [-8.225852  -7.308687  -5.717108  ... -5.4522543 -5.6776233 -6.0997114]
#   [-4.217555  -5.035489  -6.4182734 ... -2.99863   -2.0568833 -1.4937837]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-7.4942183 -7.3745522 -5.9086866 ... -5.738876  -5.458341  -4.6913724]
#   [-7.3085723 -6.569974  -7.1172037 ... -7.028376  -4.3368254 -4.210774 ]
#   [-8.509372  -8.76409   -7.8685617 ... -8.741969  -6.5852313 -4.5306807]
#   [-7.44915   -6.653825  -5.8427444 ... -5.6463704 -4.784618  -6.2613535]
#   [-6.5128717 -7.155904  -8.007486  ... -6.042004  -4.4289193 -4.4307046]]], shape=(1, 5, 100000), dtype=float32)
# خراب شد خانه
# 301.25317749001823
# 5 / 6
# tf.Tensor(
# [[[-7.9707003 -7.8801575 -4.0060496 ... -6.2122617 -6.3495693 -6.289841 ]
#   [-6.1898136 -7.146538  -6.4299693 ... -5.5885997 -5.9546204 -4.1035194]
#   [-8.421818  -8.395012  -7.079143  ... -5.347826  -6.4641232 -5.1655235]
#   [-7.756938  -7.122404  -6.8412275 ... -7.457214  -4.611618  -4.8043156]
#   [-7.0215435 -9.081573  -7.7656593 ... -4.4953136 -5.8273206 -4.2688756]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[ -8.666891   -8.136829   -5.8792458 ...  -6.364448   -6.2945786
#     -5.9453254]
#   [ -7.4042764  -6.7683625  -7.0242023 ...  -7.029165   -4.8827567
#     -4.7383647]
#   [ -9.139729   -8.11446    -8.706619  ...  -5.5023503  -6.204072
#     -5.297393 ]
#   [-10.258204  -10.210289   -7.1709685 ...  -9.826387   -7.9054017
#     -7.628722 ]
#   [ -5.3801413  -6.8556075  -7.7592754 ...  -5.2121887  -3.4503233
#     -3.1147747]]], shape=(1, 5, 100000), dtype=float32)
# tf.Tensor(
# [[[-7.75687   -7.6475244 -4.9786124 ... -6.2002454 -5.9585814 -4.853354 ]
#   [-6.038269  -6.6947055 -6.533269  ... -7.5323687 -4.670853  -2.5441647]
#   [-3.947961  -3.6488757 -6.779869  ... -2.9044244 -2.6696734 -2.064033 ]
#   [-6.1659803 -5.567388  -4.9268136 ... -5.335988  -3.1588936 -4.4715476]
#   [-5.3594036 -6.2302203 -6.3750944 ... -3.6266124 -3.3801205 -3.5707228]]], shape=(1, 5, 100000), dtype=float32)
# خراب خانه شد
# 0.00294549391240374
# 6 / 6
# ('خانه خراب شد', 2104356.07099184)
# ('خراب شد خانه', 301.25317749001823)
# ('شد خانه خراب', 8.8324934161472)
# ('خانه شد خراب', 2.714899675500319)
# ('شد خراب خانه', 0.009321286702119572)
# ('خراب خانه شد', 0.00294549391240374)
# 2104356.07099184

# %%
#delete this cell

def calculate_sentence_score(sentence_tokens):
    sentence_score = 1
    sentence = ' '.join(sentence_tokens)
    for i,token in enumerate(sentence_tokens):
        found = False
        masked_text = ' '.join(tokens[:i])+' [MASK] '+' '.join(tokens[i+1:])

        inputs = tokenizer(masked_text, return_tensors="tf")
        outputs = model(inputs)
        logits = outputs.logits

        mask_token_index = tf.where(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
        # mask_token_index = i
        mask_token_logits = logits[0, mask_token_index, :]

        k = 1000

        top_k_values, top_k_indices = tf.math.top_k(mask_token_logits, k=k)
        predicted_token_indices = top_k_indices.numpy()
        probabilities = tf.nn.softmax(top_k_values).numpy()
        predicted_tokens = tokenizer.convert_ids_to_tokens(predicted_token_indices)

        for j,predicted_token in enumerate(predicted_tokens):
            if predicted_token == token:
                sentence_score *= probabilities[j]
                # print('found',sentence_score)
                found = True
                break

        epsilon = 0.00001

        if not found:
            sentence_score *= epsilon
            # print('not found',sentence_score)

        # print(token)
        # for i in range(k):
        #     print(predicted_tokens[i],probabilities[i])
        # print('----')

    soft_parameter = 1000000000000

    return sentence_score*soft_parameter


import itertools
text = "وقتی من و دوستم برمیگشتیم از مدرسه "
tokens = tokenizer.tokenize(text)
permutations = list(itertools.permutations(tokens))
scores = []
for i,permutation in enumerate(permutations):
    print(' '.join(permutation))
    scores.append((' '.join(permutation),calculate_sentence_score(list(permutation))))
    print(i+1,'/',len(permutations))
scores.sort(key=lambda x: x[1], reverse=True)
for score in scores:
    print(score)
# Out:
# وقتی من و دوستم برمیگشتیم از مدرسه
# 1 / 5040
# وقتی من و دوستم برمیگشتیم مدرسه از
# 2 / 5040
# وقتی من و دوستم از برمیگشتیم مدرسه
# 3 / 5040
# وقتی من و دوستم از مدرسه برمیگشتیم
# 4 / 5040
# وقتی من و دوستم مدرسه برمیگشتیم از
# 5 / 5040
# وقتی من و دوستم مدرسه از برمیگشتیم
# 6 / 5040
# وقتی من و برمیگشتیم دوستم از مدرسه
# 7 / 5040
# وقتی من و برمیگشتیم دوستم مدرسه از
# 8 / 5040
# وقتی من و برمیگشتیم از دوستم مدرسه
# 9 / 5040
# وقتی من و برمیگشتیم از مدرسه دوستم
# 10 / 5040
# وقتی من و برمیگشتیم مدرسه دوستم از
# 11 / 5040
# وقتی من و برمیگشتیم مدرسه از دوستم
# 12 / 5040
# وقتی من و از دوستم برمیگشتیم مدرسه
# 13 / 5040
# وقتی من و از دوستم مدرسه برمیگشتیم
# 14 / 5040
# وقتی من و از برمیگشتیم دوستم مدرسه
# 15 / 5040
# وقتی من و از برمیگشتیم مدرسه دوستم
# 16 / 5040
# وقتی من و از مدرسه دوستم برمیگشتیم
# 17 / 5040
# وقتی من و از مدرسه برمیگشتیم دوستم
# 18 / 5040
# وقتی من و مدرسه دوستم برمیگشتیم از
# 19 / 5040
# وقتی من و مدرسه دوستم از برمیگشتیم
# 20 / 5040
# وقتی من و مدرسه برمیگشتیم دوستم از
# 21 / 5040
# وقتی من و مدرسه برمیگشتیم از دوستم
# 22 / 5040
# وقتی من و مدرسه از دوستم برمیگشتیم
# 23 / 5040
# وقتی من و مدرسه از برمیگشتیم دوستم
# 24 / 5040
# وقتی من دوستم و برمیگشتیم از مدرسه
# 25 / 5040
# وقتی من دوستم و برمیگشتیم مدرسه از
# 26 / 5040
# وقتی من دوستم و از برمیگشتیم مدرسه
# 27 / 5040
# وقتی من دوستم و از مدرسه برمیگشتیم
# 28 / 5040
# وقتی من دوستم و مدرسه برمیگشتیم از
# 29 / 5040
# وقتی من دوستم و مدرسه از برمیگشتیم
# 30 / 5040
# وقتی من دوستم برمیگشتیم و از مدرسه
# 31 / 5040
# وقتی من دوستم برمیگشتیم و مدرسه از
# 32 / 5040
# وقتی من دوستم برمیگشتیم از و مدرسه
# 33 / 5040
# وقتی من دوستم برمیگشتیم از مدرسه و
# 34 / 5040
# وقتی من دوستم برمیگشتیم مدرسه و از
# 35 / 5040
# وقتی من دوستم برمیگشتیم مدرسه از و
# 36 / 5040
# وقتی من دوستم از و برمیگشتیم مدرسه
# 37 / 5040
# وقتی من دوستم از و مدرسه برمیگشتیم
# 38 / 5040
# وقتی من دوستم از برمیگشتیم و مدرسه
# 39 / 5040
# وقتی من دوستم از برمیگشتیم مدرسه و
# 40 / 5040
# وقتی من دوستم از مدرسه و برمیگشتیم
# 41 / 5040
# وقتی من دوستم از مدرسه برمیگشتیم و
# 42 / 5040
# وقتی من دوستم مدرسه و برمیگشتیم از
# 43 / 5040
# وقتی من دوستم مدرسه و از برمیگشتیم
# 44 / 5040
# وقتی من دوستم مدرسه برمیگشتیم و از
# 45 / 5040
# وقتی من دوستم مدرسه برمیگشتیم از و
# 46 / 5040
# وقتی من دوستم مدرسه از و برمیگشتیم
# 47 / 5040
# وقتی من دوستم مدرسه از برمیگشتیم و
# 48 / 5040
# وقتی من برمیگشتیم و دوستم از مدرسه
# 49 / 5040
# وقتی من برمیگشتیم و دوستم مدرسه از
# 50 / 5040
# وقتی من برمیگشتیم و از دوستم مدرسه
# 51 / 5040
# وقتی من برمیگشتیم و از مدرسه دوستم
# 52 / 5040
# وقتی من برمیگشتیم و مدرسه دوستم از
# 53 / 5040
# وقتی من برمیگشتیم و مدرسه از دوستم
# 54 / 5040
# وقتی من برمیگشتیم دوستم و از مدرسه
# 55 / 5040
# وقتی من برمیگشتیم دوستم و مدرسه از
# 56 / 5040
# وقتی من برمیگشتیم دوستم از و مدرسه
# 57 / 5040
# وقتی من برمیگشتیم دوستم از مدرسه و
# 58 / 5040
# وقتی من برمیگشتیم دوستم مدرسه و از
# 59 / 5040
# وقتی من برمیگشتیم دوستم مدرسه از و
# 60 / 5040
# وقتی من برمیگشتیم از و دوستم مدرسه
# 61 / 5040
# وقتی من برمیگشتیم از و مدرسه دوستم
# 62 / 5040
# وقتی من برمیگشتیم از دوستم و مدرسه
# 63 / 5040
# وقتی من برمیگشتیم از دوستم مدرسه و
# 64 / 5040
# وقتی من برمیگشتیم از مدرسه و دوستم
# 65 / 5040
# وقتی من برمیگشتیم از مدرسه دوستم و
# 66 / 5040
# وقتی من برمیگشتیم مدرسه و دوستم از
# 67 / 5040
# وقتی من برمیگشتیم مدرسه و از دوستم
# 68 / 5040
# وقتی من برمیگشتیم مدرسه دوستم و از
# 69 / 5040
# وقتی من برمیگشتیم مدرسه دوستم از و
# 70 / 5040
# وقتی من برمیگشتیم مدرسه از و دوستم
# 71 / 5040
# وقتی من برمیگشتیم مدرسه از دوستم و
# 72 / 5040
# وقتی من از و دوستم برمیگشتیم مدرسه
# 73 / 5040
# وقتی من از و دوستم مدرسه برمیگشتیم
# 74 / 5040
# وقتی من از و برمیگشتیم دوستم مدرسه
# 75 / 5040
# وقتی من از و برمیگشتیم مدرسه دوستم
# 76 / 5040
# وقتی من از و مدرسه دوستم برمیگشتیم
# 77 / 5040
# وقتی من از و مدرسه برمیگشتیم دوستم
# 78 / 5040
# وقتی من از دوستم و برمیگشتیم مدرسه
# 79 / 5040
# وقتی من از دوستم و مدرسه برمیگشتیم
# 80 / 5040
# وقتی من از دوستم برمیگشتیم و مدرسه
# 81 / 5040
# وقتی من از دوستم برمیگشتیم مدرسه و
# 82 / 5040
# وقتی من از دوستم مدرسه و برمیگشتیم
# 83 / 5040
# وقتی من از دوستم مدرسه برمیگشتیم و
# 84 / 5040
# وقتی من از برمیگشتیم و دوستم مدرسه
# 85 / 5040
# وقتی من از برمیگشتیم و مدرسه دوستم
# 86 / 5040
# وقتی من از برمیگشتیم دوستم و مدرسه
# 87 / 5040
# وقتی من از برمیگشتیم دوستم مدرسه و
# 88 / 5040
# وقتی من از برمیگشتیم مدرسه و دوستم
# 89 / 5040
# وقتی من از برمیگشتیم مدرسه دوستم و
# 90 / 5040
# وقتی من از مدرسه و دوستم برمیگشتیم
# 91 / 5040
# وقتی من از مدرسه و برمیگشتیم دوستم
# 92 / 5040
# وقتی من از مدرسه دوستم و برمیگشتیم
# 93 / 5040
# وقتی من از مدرسه دوستم برمیگشتیم و
# 94 / 5040
# وقتی من از مدرسه برمیگشتیم و دوستم
# 95 / 5040
# وقتی من از مدرسه برمیگشتیم دوستم و
# 96 / 5040
# وقتی من مدرسه و دوستم برمیگشتیم از
# 97 / 5040
# وقتی من مدرسه و دوستم از برمیگشتیم
# 98 / 5040
# وقتی من مدرسه و برمیگشتیم دوستم از
# 99 / 5040
# وقتی من مدرسه و برمیگشتیم از دوستم
# 100 / 5040
# وقتی من مدرسه و از دوستم برمیگشتیم
# 101 / 5040
# وقتی من مدرسه و از برمیگشتیم دوستم
# 102 / 5040
# وقتی من مدرسه دوستم و برمیگشتیم از
# 103 / 5040
# وقتی من مدرسه دوستم و از برمیگشتیم
# 104 / 5040
# وقتی من مدرسه دوستم برمیگشتیم و از
# 105 / 5040
# وقتی من مدرسه دوستم برمیگشتیم از و
# 106 / 5040
# وقتی من مدرسه دوستم از و برمیگشتیم
# 107 / 5040
# وقتی من مدرسه دوستم از برمیگشتیم و
# 108 / 5040
# وقتی من مدرسه برمیگشتیم و دوستم از
# 109 / 5040
# وقتی من مدرسه برمیگشتیم و از دوستم
# 110 / 5040
# وقتی من مدرسه برمیگشتیم دوستم و از
# 111 / 5040
# وقتی من مدرسه برمیگشتیم دوستم از و
# 112 / 5040
# وقتی من مدرسه برمیگشتیم از و دوستم
# 113 / 5040
# وقتی من مدرسه برمیگشتیم از دوستم و
# 114 / 5040
# وقتی من مدرسه از و دوستم برمیگشتیم
# 115 / 5040
# وقتی من مدرسه از و برمیگشتیم دوستم
# 116 / 5040
# وقتی من مدرسه از دوستم و برمیگشتیم
# 117 / 5040
# وقتی من مدرسه از دوستم برمیگشتیم و
# 118 / 5040
# وقتی من مدرسه از برمیگشتیم و دوستم
# 119 / 5040
# وقتی من مدرسه از برمیگشتیم دوستم و
# 120 / 5040
# وقتی و من دوستم برمیگشتیم از مدرسه
# 121 / 5040
# وقتی و من دوستم برمیگشتیم مدرسه از
# 122 / 5040
# وقتی و من دوستم از برمیگشتیم مدرسه
# 123 / 5040
# وقتی و من دوستم از مدرسه برمیگشتیم
# 124 / 5040
# وقتی و من دوستم مدرسه برمیگشتیم از
# 125 / 5040
# وقتی و من دوستم مدرسه از برمیگشتیم
# 126 / 5040
# وقتی و من برمیگشتیم دوستم از مدرسه
# 127 / 5040
# وقتی و من برمیگشتیم دوستم مدرسه از
# 128 / 5040
# وقتی و من برمیگشتیم از دوستم مدرسه
# 129 / 5040
# وقتی و من برمیگشتیم از مدرسه دوستم
# 130 / 5040
# وقتی و من برمیگشتیم مدرسه دوستم از
# 131 / 5040
# وقتی و من برمیگشتیم مدرسه از دوستم
# 132 / 5040
# وقتی و من از دوستم برمیگشتیم مدرسه
# 133 / 5040
# وقتی و من از دوستم مدرسه برمیگشتیم
# 134 / 5040
# وقتی و من از برمیگشتیم دوستم مدرسه
# 135 / 5040
# وقتی و من از برمیگشتیم مدرسه دوستم
# 136 / 5040
# وقتی و من از مدرسه دوستم برمیگشتیم
# 137 / 5040
# وقتی و من از مدرسه برمیگشتیم دوستم
# 138 / 5040
# وقتی و من مدرسه دوستم برمیگشتیم از
# 139 / 5040
# وقتی و من مدرسه دوستم از برمیگشتیم
# 140 / 5040
# وقتی و من مدرسه برمیگشتیم دوستم از
# 141 / 5040
# وقتی و من مدرسه برمیگشتیم از دوستم
# 142 / 5040
# وقتی و من مدرسه از دوستم برمیگشتیم
# 143 / 5040
# وقتی و من مدرسه از برمیگشتیم دوستم
# 144 / 5040
# وقتی و دوستم من برمیگشتیم از مدرسه
# 145 / 5040
# وقتی و دوستم من برمیگشتیم مدرسه از
# 146 / 5040
# وقتی و دوستم من از برمیگشتیم مدرسه
# 147 / 5040
# وقتی و دوستم من از مدرسه برمیگشتیم
# 148 / 5040
# وقتی و دوستم من مدرسه برمیگشتیم از
# 149 / 5040
# وقتی و دوستم من مدرسه از برمیگشتیم
# 150 / 5040
# وقتی و دوستم برمیگشتیم من از مدرسه
# 151 / 5040
# وقتی و دوستم برمیگشتیم من مدرسه از
# 152 / 5040
# وقتی و دوستم برمیگشتیم از من مدرسه
# 153 / 5040
# وقتی و دوستم برمیگشتیم از مدرسه من
# 154 / 5040
# وقتی و دوستم برمیگشتیم مدرسه من از
# 155 / 5040
# وقتی و دوستم برمیگشتیم مدرسه از من
# 156 / 5040
# وقتی و دوستم از من برمیگشتیم مدرسه
# 157 / 5040
# وقتی و دوستم از من مدرسه برمیگشتیم
# 158 / 5040
# وقتی و دوستم از برمیگشتیم من مدرسه
# 159 / 5040
# وقتی و دوستم از برمیگشتیم مدرسه من
# 160 / 5040
# وقتی و دوستم از مدرسه من برمیگشتیم
# 161 / 5040
# وقتی و دوستم از مدرسه برمیگشتیم من
# 162 / 5040
# وقتی و دوستم مدرسه من برمیگشتیم از
# 163 / 5040
# وقتی و دوستم مدرسه من از برمیگشتیم
# 164 / 5040
# وقتی و دوستم مدرسه برمیگشتیم من از
# 165 / 5040
# وقتی و دوستم مدرسه برمیگشتیم از من
# 166 / 5040
# وقتی و دوستم مدرسه از من برمیگشتیم
# 167 / 5040
# وقتی و دوستم مدرسه از برمیگشتیم من
# 168 / 5040
# وقتی و برمیگشتیم من دوستم از مدرسه
# 169 / 5040
# وقتی و برمیگشتیم من دوستم مدرسه از
# 170 / 5040
# وقتی و برمیگشتیم من از دوستم مدرسه
# 171 / 5040
# وقتی و برمیگشتیم من از مدرسه دوستم
# 172 / 5040
# وقتی و برمیگشتیم من مدرسه دوستم از
# 173 / 5040
# وقتی و برمیگشتیم من مدرسه از دوستم
# 174 / 5040
# وقتی و برمیگشتیم دوستم من از مدرسه
# 175 / 5040
# وقتی و برمیگشتیم دوستم من مدرسه از
# 176 / 5040
# وقتی و برمیگشتیم دوستم از من مدرسه
# 177 / 5040
# وقتی و برمیگشتیم دوستم از مدرسه من
# 178 / 5040
# وقتی و برمیگشتیم دوستم مدرسه من از
# 179 / 5040
# وقتی و برمیگشتیم دوستم مدرسه از من
# 180 / 5040
# وقتی و برمیگشتیم از من دوستم مدرسه
# 181 / 5040
# وقتی و برمیگشتیم از من مدرسه دوستم
# 182 / 5040
# وقتی و برمیگشتیم از دوستم من مدرسه
# 183 / 5040
# وقتی و برمیگشتیم از دوستم مدرسه من
# 184 / 5040
# وقتی و برمیگشتیم از مدرسه من دوستم
# 185 / 5040
# وقتی و برمیگشتیم از مدرسه دوستم من
# 186 / 5040
# وقتی و برمیگشتیم مدرسه من دوستم از
# 187 / 5040
# وقتی و برمیگشتیم مدرسه من از دوستم
# 188 / 5040
# وقتی و برمیگشتیم مدرسه دوستم من از
# 189 / 5040
# وقتی و برمیگشتیم مدرسه دوستم از من
# 190 / 5040
# وقتی و برمیگشتیم مدرسه از من دوستم
# 191 / 5040
# وقتی و برمیگشتیم مدرسه از دوستم من
# 192 / 5040
# وقتی و از من دوستم برمیگشتیم مدرسه
# 193 / 5040
# وقتی و از من دوستم مدرسه برمیگشتیم
# 194 / 5040
# وقتی و از من برمیگشتیم دوستم مدرسه
# 195 / 5040
# وقتی و از من برمیگشتیم مدرسه دوستم
# 196 / 5040
# وقتی و از من مدرسه دوستم برمیگشتیم
# 197 / 5040
# وقتی و از من مدرسه برمیگشتیم دوستم
# 198 / 5040
# وقتی و از دوستم من برمیگشتیم مدرسه
# 199 / 5040
# وقتی و از دوستم من مدرسه برمیگشتیم
# 200 / 5040
# وقتی و از دوستم برمیگشتیم من مدرسه
# 201 / 5040
# وقتی و از دوستم برمیگشتیم مدرسه من
# 202 / 5040
# وقتی و از دوستم مدرسه من برمیگشتیم
# 203 / 5040
# وقتی و از دوستم مدرسه برمیگشتیم من
# 204 / 5040
# وقتی و از برمیگشتیم من دوستم مدرسه
# 205 / 5040
# وقتی و از برمیگشتیم من مدرسه دوستم
# 206 / 5040
# وقتی و از برمیگشتیم دوستم من مدرسه
# 207 / 5040
# وقتی و از برمیگشتیم دوستم مدرسه من
# 208 / 5040
# وقتی و از برمیگشتیم مدرسه من دوستم
# 209 / 5040
# وقتی و از برمیگشتیم مدرسه دوستم من
# 210 / 5040
# وقتی و از مدرسه من دوستم برمیگشتیم
# 211 / 5040
# وقتی و از مدرسه من برمیگشتیم دوستم
# 212 / 5040
# وقتی و از مدرسه دوستم من برمیگشتیم
# 213 / 5040
# وقتی و از مدرسه دوستم برمیگشتیم من
# 214 / 5040
# وقتی و از مدرسه برمیگشتیم من دوستم
# 215 / 5040
# وقتی و از مدرسه برمیگشتیم دوستم من
# 216 / 5040
# وقتی و مدرسه من دوستم برمیگشتیم از
# 217 / 5040
# وقتی و مدرسه من دوستم از برمیگشتیم
# 218 / 5040
# وقتی و مدرسه من برمیگشتیم دوستم از
# 219 / 5040
# وقتی و مدرسه من برمیگشتیم از دوستم
# 220 / 5040
# وقتی و مدرسه من از دوستم برمیگشتیم
# 221 / 5040
# وقتی و مدرسه من از برمیگشتیم دوستم
# 222 / 5040
# وقتی و مدرسه دوستم من برمیگشتیم از
# 223 / 5040
# وقتی و مدرسه دوستم من از برمیگشتیم
# 224 / 5040
# وقتی و مدرسه دوستم برمیگشتیم من از
# 225 / 5040
# وقتی و مدرسه دوستم برمیگشتیم از من
# 226 / 5040
# وقتی و مدرسه دوستم از من برمیگشتیم
# 227 / 5040
# وقتی و مدرسه دوستم از برمیگشتیم من
# 228 / 5040
# وقتی و مدرسه برمیگشتیم من دوستم از
# 229 / 5040
# وقتی و مدرسه برمیگشتیم من از دوستم
# 230 / 5040
# وقتی و مدرسه برمیگشتیم دوستم من از
# 231 / 5040
# وقتی و مدرسه برمیگشتیم دوستم از من
# 232 / 5040
# وقتی و مدرسه برمیگشتیم از من دوستم
# 233 / 5040
# وقتی و مدرسه برمیگشتیم از دوستم من
# 234 / 5040
# وقتی و مدرسه از من دوستم برمیگشتیم
# 235 / 5040
# وقتی و مدرسه از من برمیگشتیم دوستم
# 236 / 5040
# وقتی و مدرسه از دوستم من برمیگشتیم
# 237 / 5040
# وقتی و مدرسه از دوستم برمیگشتیم من
# 238 / 5040
# وقتی و مدرسه از برمیگشتیم من دوستم
# 239 / 5040
# وقتی و مدرسه از برمیگشتیم دوستم من
# 240 / 5040
# وقتی دوستم من و برمیگشتیم از مدرسه
# 241 / 5040
# وقتی دوستم من و برمیگشتیم مدرسه از
# 242 / 5040
# وقتی دوستم من و از برمیگشتیم مدرسه
# 243 / 5040
# وقتی دوستم من و از مدرسه برمیگشتیم
# 244 / 5040
# وقتی دوستم من و مدرسه برمیگشتیم از
# 245 / 5040
# وقتی دوستم من و مدرسه از برمیگشتیم
# 246 / 5040
# وقتی دوستم من برمیگشتیم و از مدرسه
# 247 / 5040
# وقتی دوستم من برمیگشتیم و مدرسه از
# 248 / 5040
# وقتی دوستم من برمیگشتیم از و مدرسه
# 249 / 5040
# وقتی دوستم من برمیگشتیم از مدرسه و
# 250 / 5040
# وقتی دوستم من برمیگشتیم مدرسه و از
# 251 / 5040
# وقتی دوستم من برمیگشتیم مدرسه از و
# 252 / 5040
# وقتی دوستم من از و برمیگشتیم مدرسه
# 253 / 5040
# وقتی دوستم من از و مدرسه برمیگشتیم
# 254 / 5040
# وقتی دوستم من از برمیگشتیم و مدرسه
# 255 / 5040
# وقتی دوستم من از برمیگشتیم مدرسه و
# 256 / 5040
# وقتی دوستم من از مدرسه و برمیگشتیم
# 257 / 5040
# وقتی دوستم من از مدرسه برمیگشتیم و
# 258 / 5040
# وقتی دوستم من مدرسه و برمیگشتیم از
# 259 / 5040
# وقتی دوستم من مدرسه و از برمیگشتیم
# 260 / 5040
# وقتی دوستم من مدرسه برمیگشتیم و از
# 261 / 5040
# وقتی دوستم من مدرسه برمیگشتیم از و
# 262 / 5040
# وقتی دوستم من مدرسه از و برمیگشتیم
# 263 / 5040
# وقتی دوستم من مدرسه از برمیگشتیم و
# 264 / 5040
# وقتی دوستم و من برمیگشتیم از مدرسه
# 265 / 5040
# وقتی دوستم و من برمیگشتیم مدرسه از
# 266 / 5040
# وقتی دوستم و من از برمیگشتیم مدرسه
# 267 / 5040
# وقتی دوستم و من از مدرسه برمیگشتیم
# 268 / 5040
# وقتی دوستم و من مدرسه برمیگشتیم از
# 269 / 5040
# وقتی دوستم و من مدرسه از برمیگشتیم
# 270 / 5040
# وقتی دوستم و برمیگشتیم من از مدرسه
# 271 / 5040
# وقتی دوستم و برمیگشتیم من مدرسه از
# 272 / 5040
# وقتی دوستم و برمیگشتیم از من مدرسه
# 273 / 5040
# وقتی دوستم و برمیگشتیم از مدرسه من
# 274 / 5040
# وقتی دوستم و برمیگشتیم مدرسه من از
# 275 / 5040
# وقتی دوستم و برمیگشتیم مدرسه از من
# 276 / 5040
# وقتی دوستم و از من برمیگشتیم مدرسه
# 277 / 5040
# وقتی دوستم و از من مدرسه برمیگشتیم
# 278 / 5040
# وقتی دوستم و از برمیگشتیم من مدرسه
# 279 / 5040
# وقتی دوستم و از برمیگشتیم مدرسه من
# 280 / 5040
# وقتی دوستم و از مدرسه من برمیگشتیم
# 281 / 5040
# وقتی دوستم و از مدرسه برمیگشتیم من
# 282 / 5040
# وقتی دوستم و مدرسه من برمیگشتیم از
# 283 / 5040
# وقتی دوستم و مدرسه من از برمیگشتیم
# 284 / 5040
# وقتی دوستم و مدرسه برمیگشتیم من از
# 285 / 5040
# وقتی دوستم و مدرسه برمیگشتیم از من
# 286 / 5040
# وقتی دوستم و مدرسه از من برمیگشتیم
# 287 / 5040
# وقتی دوستم و مدرسه از برمیگشتیم من
# 288 / 5040
# وقتی دوستم برمیگشتیم من و از مدرسه
# 289 / 5040
# وقتی دوستم برمیگشتیم من و مدرسه از
# 290 / 5040
# وقتی دوستم برمیگشتیم من از و مدرسه
# 291 / 5040
# وقتی دوستم برمیگشتیم من از مدرسه و
# 292 / 5040
# وقتی دوستم برمیگشتیم من مدرسه و از
# 293 / 5040
# وقتی دوستم برمیگشتیم من مدرسه از و
# 294 / 5040
# وقتی دوستم برمیگشتیم و من از مدرسه
# 295 / 5040
# وقتی دوستم برمیگشتیم و من مدرسه از
# 296 / 5040
# وقتی دوستم برمیگشتیم و از من مدرسه
# 297 / 5040
# وقتی دوستم برمیگشتیم و از مدرسه من
# 298 / 5040
# وقتی دوستم برمیگشتیم و مدرسه من از
# 299 / 5040
# وقتی دوستم برمیگشتیم و مدرسه از من
# 300 / 5040
# وقتی دوستم برمیگشتیم از من و مدرسه
# 301 / 5040
# وقتی دوستم برمیگشتیم از من مدرسه و
# 302 / 5040
# وقتی دوستم برمیگشتیم از و من مدرسه
# 303 / 5040
# وقتی دوستم برمیگشتیم از و مدرسه من
# 304 / 5040
# وقتی دوستم برمیگشتیم از مدرسه من و
# 305 / 5040
# وقتی دوستم برمیگشتیم از مدرسه و من
# 306 / 5040
# وقتی دوستم برمیگشتیم مدرسه من و از
# 307 / 5040
# وقتی دوستم برمیگشتیم مدرسه من از و
# 308 / 5040
# وقتی دوستم برمیگشتیم مدرسه و من از
# 309 / 5040
# وقتی دوستم برمیگشتیم مدرسه و از من
# 310 / 5040
# وقتی دوستم برمیگشتیم مدرسه از من و
# 311 / 5040
# وقتی دوستم برمیگشتیم مدرسه از و من
# 312 / 5040
# وقتی دوستم از من و برمیگشتیم مدرسه
# 313 / 5040
# وقتی دوستم از من و مدرسه برمیگشتیم
# 314 / 5040
# وقتی دوستم از من برمیگشتیم و مدرسه
# 315 / 5040
# وقتی دوستم از من برمیگشتیم مدرسه و
# 316 / 5040
# وقتی دوستم از من مدرسه و برمیگشتیم
# 317 / 5040
# وقتی دوستم از من مدرسه برمیگشتیم و
# 318 / 5040
# وقتی دوستم از و من برمیگشتیم مدرسه
# 319 / 5040
# وقتی دوستم از و من مدرسه برمیگشتیم
# 320 / 5040
# وقتی دوستم از و برمیگشتیم من مدرسه
# 321 / 5040
# وقتی دوستم از و برمیگشتیم مدرسه من
# 322 / 5040
# وقتی دوستم از و مدرسه من برمیگشتیم
# 323 / 5040
# وقتی دوستم از و مدرسه برمیگشتیم من
# 324 / 5040
# وقتی دوستم از برمیگشتیم من و مدرسه
# 325 / 5040
# وقتی دوستم از برمیگشتیم من مدرسه و
# 326 / 5040
# وقتی دوستم از برمیگشتیم و من مدرسه
# 327 / 5040
# وقتی دوستم از برمیگشتیم و مدرسه من
# 328 / 5040
# وقتی دوستم از برمیگشتیم مدرسه من و
# 329 / 5040
# وقتی دوستم از برمیگشتیم مدرسه و من
# 330 / 5040
# وقتی دوستم از مدرسه من و برمیگشتیم
# 331 / 5040
# وقتی دوستم از مدرسه من برمیگشتیم و
# 332 / 5040
# وقتی دوستم از مدرسه و من برمیگشتیم
# 333 / 5040
# وقتی دوستم از مدرسه و برمیگشتیم من
# 334 / 5040
# وقتی دوستم از مدرسه برمیگشتیم من و
# 335 / 5040
# وقتی دوستم از مدرسه برمیگشتیم و من
# 336 / 5040
# وقتی دوستم مدرسه من و برمیگشتیم از
# 337 / 5040
# وقتی دوستم مدرسه من و از برمیگشتیم
# 338 / 5040
# وقتی دوستم مدرسه من برمیگشتیم و از
# 339 / 5040
# وقتی دوستم مدرسه من برمیگشتیم از و
# 340 / 5040
# وقتی دوستم مدرسه من از و برمیگشتیم
# 341 / 5040
# وقتی دوستم مدرسه من از برمیگشتیم و
# 342 / 5040
# وقتی دوستم مدرسه و من برمیگشتیم از
# 343 / 5040
# وقتی دوستم مدرسه و من از برمیگشتیم
# 344 / 5040
# وقتی دوستم مدرسه و برمیگشتیم من از
# 345 / 5040
# وقتی دوستم مدرسه و برمیگشتیم از من
# 346 / 5040
# وقتی دوستم مدرسه و از من برمیگشتیم
# 347 / 5040
# وقتی دوستم مدرسه و از برمیگشتیم من
# 348 / 5040
# وقتی دوستم مدرسه برمیگشتیم من و از
# 349 / 5040
# وقتی دوستم مدرسه برمیگشتیم من از و
# 350 / 5040
# وقتی دوستم مدرسه برمیگشتیم و من از
# 351 / 5040
# وقتی دوستم مدرسه برمیگشتیم و از من
# 352 / 5040
# وقتی دوستم مدرسه برمیگشتیم از من و
# 353 / 5040
# وقتی دوستم مدرسه برمیگشتیم از و من
# 354 / 5040
# وقتی دوستم مدرسه از من و برمیگشتیم
# 355 / 5040
# وقتی دوستم مدرسه از من برمیگشتیم و
# 356 / 5040
# وقتی دوستم مدرسه از و من برمیگشتیم
# 357 / 5040
# وقتی دوستم مدرسه از و برمیگشتیم من
# 358 / 5040
# وقتی دوستم مدرسه از برمیگشتیم من و
# 359 / 5040
# وقتی دوستم مدرسه از برمیگشتیم و من
# 360 / 5040
# وقتی برمیگشتیم من و دوستم از مدرسه
# 361 / 5040
# وقتی برمیگشتیم من و دوستم مدرسه از
# 362 / 5040
# وقتی برمیگشتیم من و از دوستم مدرسه
# 363 / 5040
# وقتی برمیگشتیم من و از مدرسه دوستم
# 364 / 5040
# وقتی برمیگشتیم من و مدرسه دوستم از
# 365 / 5040
# وقتی برمیگشتیم من و مدرسه از دوستم
# 366 / 5040
# وقتی برمیگشتیم من دوستم و از مدرسه
# 367 / 5040
# وقتی برمیگشتیم من دوستم و مدرسه از
# 368 / 5040
# وقتی برمیگشتیم من دوستم از و مدرسه
# 369 / 5040
# وقتی برمیگشتیم من دوستم از مدرسه و
# 370 / 5040
# وقتی برمیگشتیم من دوستم مدرسه و از
# 371 / 5040
# وقتی برمیگشتیم من دوستم مدرسه از و
# 372 / 5040
# وقتی برمیگشتیم من از و دوستم مدرسه
# 373 / 5040
# وقتی برمیگشتیم من از و مدرسه دوستم
# 374 / 5040
# وقتی برمیگشتیم من از دوستم و مدرسه
# 375 / 5040
# وقتی برمیگشتیم من از دوستم مدرسه و
# 376 / 5040
# وقتی برمیگشتیم من از مدرسه و دوستم
# 377 / 5040
# وقتی برمیگشتیم من از مدرسه دوستم و
# 378 / 5040
# وقتی برمیگشتیم من مدرسه و دوستم از
# 379 / 5040
# وقتی برمیگشتیم من مدرسه و از دوستم
# 380 / 5040
# وقتی برمیگشتیم من مدرسه دوستم و از
# 381 / 5040
# وقتی برمیگشتیم من مدرسه دوستم از و
# 382 / 5040
# وقتی برمیگشتیم من مدرسه از و دوستم
# 383 / 5040
# وقتی برمیگشتیم من مدرسه از دوستم و
# 384 / 5040
# وقتی برمیگشتیم و من دوستم از مدرسه
# 385 / 5040
# وقتی برمیگشتیم و من دوستم مدرسه از
# 386 / 5040
# وقتی برمیگشتیم و من از دوستم مدرسه
# 387 / 5040
# وقتی برمیگشتیم و من از مدرسه دوستم
# 388 / 5040
# وقتی برمیگشتیم و من مدرسه دوستم از
# 389 / 5040
# وقتی برمیگشتیم و من مدرسه از دوستم
# 390 / 5040
# وقتی برمیگشتیم و دوستم من از مدرسه
# 391 / 5040
# وقتی برمیگشتیم و دوستم من مدرسه از
# 392 / 5040
# وقتی برمیگشتیم و دوستم از من مدرسه
# 393 / 5040
# وقتی برمیگشتیم و دوستم از مدرسه من
# 394 / 5040
# وقتی برمیگشتیم و دوستم مدرسه من از
# 395 / 5040
# وقتی برمیگشتیم و دوستم مدرسه از من
# 396 / 5040
# وقتی برمیگشتیم و از من دوستم مدرسه
# 397 / 5040
# وقتی برمیگشتیم و از من مدرسه دوستم
# 398 / 5040
# وقتی برمیگشتیم و از دوستم من مدرسه
# 399 / 5040
# وقتی برمیگشتیم و از دوستم مدرسه من
# 400 / 5040
# وقتی برمیگشتیم و از مدرسه من دوستم
# 401 / 5040
# وقتی برمیگشتیم و از مدرسه دوستم من
# 402 / 5040
# وقتی برمیگشتیم و مدرسه من دوستم از
# 403 / 5040
# وقتی برمیگشتیم و مدرسه من از دوستم
# 404 / 5040
# وقتی برمیگشتیم و مدرسه دوستم من از
# 405 / 5040
# وقتی برمیگشتیم و مدرسه دوستم از من
# 406 / 5040
# وقتی برمیگشتیم و مدرسه از من دوستم
# 407 / 5040
# وقتی برمیگشتیم و مدرسه از دوستم من
# 408 / 5040
# وقتی برمیگشتیم دوستم من و از مدرسه
# 409 / 5040
# وقتی برمیگشتیم دوستم من و مدرسه از
# 410 / 5040
# وقتی برمیگشتیم دوستم من از و مدرسه
# 411 / 5040
# وقتی برمیگشتیم دوستم من از مدرسه و
# 412 / 5040
# وقتی برمیگشتیم دوستم من مدرسه و از
# 413 / 5040
# وقتی برمیگشتیم دوستم من مدرسه از و
# 414 / 5040
# وقتی برمیگشتیم دوستم و من از مدرسه
# 415 / 5040
# وقتی برمیگشتیم دوستم و من مدرسه از
# 416 / 5040
# وقتی برمیگشتیم دوستم و از من مدرسه
# 417 / 5040
# وقتی برمیگشتیم دوستم و از مدرسه من
# 418 / 5040
# وقتی برمیگشتیم دوستم و مدرسه من از
# 419 / 5040
# وقتی برمیگشتیم دوستم و مدرسه از من
# 420 / 5040
# وقتی برمیگشتیم دوستم از من و مدرسه
# 421 / 5040
# وقتی برمیگشتیم دوستم از من مدرسه و
# 422 / 5040
# وقتی برمیگشتیم دوستم از و من مدرسه
# 423 / 5040
# وقتی برمیگشتیم دوستم از و مدرسه من
# 424 / 5040
# وقتی برمیگشتیم دوستم از مدرسه من و
# 425 / 5040
# وقتی برمیگشتیم دوستم از مدرسه و من
# 426 / 5040
# وقتی برمیگشتیم دوستم مدرسه من و از
# 427 / 5040
# وقتی برمیگشتیم دوستم مدرسه من از و
# 428 / 5040
# وقتی برمیگشتیم دوستم مدرسه و من از
# 429 / 5040
# وقتی برمیگشتیم دوستم مدرسه و از من
# 430 / 5040
# وقتی برمیگشتیم دوستم مدرسه از من و
# 431 / 5040
# وقتی برمیگشتیم دوستم مدرسه از و من
# 432 / 5040
# وقتی برمیگشتیم از من و دوستم مدرسه
# 433 / 5040
# وقتی برمیگشتیم از من و مدرسه دوستم
# 434 / 5040
# وقتی برمیگشتیم از من دوستم و مدرسه
# 435 / 5040
# وقتی برمیگشتیم از من دوستم مدرسه و
# 436 / 5040
# وقتی برمیگشتیم از من مدرسه و دوستم
# 437 / 5040
# وقتی برمیگشتیم از من مدرسه دوستم و
# 438 / 5040
# وقتی برمیگشتیم از و من دوستم مدرسه
# 439 / 5040
# وقتی برمیگشتیم از و من مدرسه دوستم
# 440 / 5040
# وقتی برمیگشتیم از و دوستم من مدرسه
# 441 / 5040
# وقتی برمیگشتیم از و دوستم مدرسه من
# 442 / 5040
# وقتی برمیگشتیم از و مدرسه من دوستم
# 443 / 5040
# وقتی برمیگشتیم از و مدرسه دوستم من
# 444 / 5040
# وقتی برمیگشتیم از دوستم من و مدرسه
# 445 / 5040
# وقتی برمیگشتیم از دوستم من مدرسه و
# 446 / 5040
# وقتی برمیگشتیم از دوستم و من مدرسه
# 447 / 5040
# وقتی برمیگشتیم از دوستم و مدرسه من
# 448 / 5040
# وقتی برمیگشتیم از دوستم مدرسه من و
# 449 / 5040
# وقتی برمیگشتیم از دوستم مدرسه و من
# 450 / 5040
# وقتی برمیگشتیم از مدرسه من و دوستم
# 451 / 5040
# وقتی برمیگشتیم از مدرسه من دوستم و
# 452 / 5040
# وقتی برمیگشتیم از مدرسه و من دوستم
# 453 / 5040
# وقتی برمیگشتیم از مدرسه و دوستم من
# 454 / 5040
# وقتی برمیگشتیم از مدرسه دوستم من و
# 455 / 5040
# وقتی برمیگشتیم از مدرسه دوستم و من
# 456 / 5040
# وقتی برمیگشتیم مدرسه من و دوستم از
# 457 / 5040
# وقتی برمیگشتیم مدرسه من و از دوستم
# 458 / 5040
# وقتی برمیگشتیم مدرسه من دوستم و از
# 459 / 5040
# وقتی برمیگشتیم مدرسه من دوستم از و
# 460 / 5040
# وقتی برمیگشتیم مدرسه من از و دوستم
# 461 / 5040
# وقتی برمیگشتیم مدرسه من از دوستم و
# 462 / 5040
# وقتی برمیگشتیم مدرسه و من دوستم از
# 463 / 5040
# وقتی برمیگشتیم مدرسه و من از دوستم
# 464 / 5040
# وقتی برمیگشتیم مدرسه و دوستم من از
# 465 / 5040
# وقتی برمیگشتیم مدرسه و دوستم از من
# 466 / 5040
# وقتی برمیگشتیم مدرسه و از من دوستم
# 467 / 5040
# وقتی برمیگشتیم مدرسه و از دوستم من
# 468 / 5040
# وقتی برمیگشتیم مدرسه دوستم من و از
# 469 / 5040
# وقتی برمیگشتیم مدرسه دوستم من از و
# 470 / 5040
# وقتی برمیگشتیم مدرسه دوستم و من از
# 471 / 5040
# وقتی برمیگشتیم مدرسه دوستم و از من
# 472 / 5040
# وقتی برمیگشتیم مدرسه دوستم از من و
# 473 / 5040
# وقتی برمیگشتیم مدرسه دوستم از و من
# 474 / 5040
# وقتی برمیگشتیم مدرسه از من و دوستم
# 475 / 5040
# وقتی برمیگشتیم مدرسه از من دوستم و
# 476 / 5040
# وقتی برمیگشتیم مدرسه از و من دوستم
# 477 / 5040
# وقتی برمیگشتیم مدرسه از و دوستم من
# 478 / 5040
# وقتی برمیگشتیم مدرسه از دوستم من و
# 479 / 5040
# وقتی برمیگشتیم مدرسه از دوستم و من
# 480 / 5040
# وقتی از من و دوستم برمیگشتیم مدرسه
# 481 / 5040
# وقتی از من و دوستم مدرسه برمیگشتیم
# 482 / 5040
# وقتی از من و برمیگشتیم دوستم مدرسه
# 483 / 5040
# وقتی از من و برمیگشتیم مدرسه دوستم
# 484 / 5040
# وقتی از من و مدرسه دوستم برمیگشتیم
# 485 / 5040
# وقتی از من و مدرسه برمیگشتیم دوستم
# 486 / 5040
# وقتی از من دوستم و برمیگشتیم مدرسه
# 487 / 5040
# وقتی از من دوستم و مدرسه برمیگشتیم
# 488 / 5040
# وقتی از من دوستم برمیگشتیم و مدرسه
# 489 / 5040
# وقتی از من دوستم برمیگشتیم مدرسه و
# 490 / 5040
# وقتی از من دوستم مدرسه و برمیگشتیم
# 491 / 5040
# وقتی از من دوستم مدرسه برمیگشتیم و
# 492 / 5040
# وقتی از من برمیگشتیم و دوستم مدرسه
# 493 / 5040
# وقتی از من برمیگشتیم و مدرسه دوستم
# 494 / 5040
# وقتی از من برمیگشتیم دوستم و مدرسه
# 495 / 5040
# وقتی از من برمیگشتیم دوستم مدرسه و
# 496 / 5040
# وقتی از من برمیگشتیم مدرسه و دوستم
# 497 / 5040
# وقتی از من برمیگشتیم مدرسه دوستم و
# 498 / 5040
# وقتی از من مدرسه و دوستم برمیگشتیم
# 499 / 5040
# وقتی از من مدرسه و برمیگشتیم دوستم
# 500 / 5040
# وقتی از من مدرسه دوستم و برمیگشتیم
# 501 / 5040
# وقتی از من مدرسه دوستم برمیگشتیم و
# 502 / 5040
# وقتی از من مدرسه برمیگشتیم و دوستم
# 503 / 5040
# وقتی از من مدرسه برمیگشتیم دوستم و
# 504 / 5040
# وقتی از و من دوستم برمیگشتیم مدرسه
# 505 / 5040
# وقتی از و من دوستم مدرسه برمیگشتیم
# 506 / 5040
# وقتی از و من برمیگشتیم دوستم مدرسه
# 507 / 5040
# وقتی از و من برمیگشتیم مدرسه دوستم
# 508 / 5040
# وقتی از و من مدرسه دوستم برمیگشتیم
# 509 / 5040
# وقتی از و من مدرسه برمیگشتیم دوستم
# 510 / 5040
# وقتی از و دوستم من برمیگشتیم مدرسه
# 511 / 5040
# وقتی از و دوستم من مدرسه برمیگشتیم
# 512 / 5040
# وقتی از و دوستم برمیگشتیم من مدرسه
# 513 / 5040
# وقتی از و دوستم برمیگشتیم مدرسه من
# 514 / 5040
# وقتی از و دوستم مدرسه من برمیگشتیم
# 515 / 5040
# وقتی از و دوستم مدرسه برمیگشتیم من
# 516 / 5040
# وقتی از و برمیگشتیم من دوستم مدرسه
# 517 / 5040
# وقتی از و برمیگشتیم من مدرسه دوستم
# 518 / 5040
# وقتی از و برمیگشتیم دوستم من مدرسه
# 519 / 5040
# وقتی از و برمیگشتیم دوستم مدرسه من
# 520 / 5040
# وقتی از و برمیگشتیم مدرسه من دوستم
# 521 / 5040
# وقتی از و برمیگشتیم مدرسه دوستم من
# 522 / 5040
# وقتی از و مدرسه من دوستم برمیگشتیم
# 523 / 5040
# وقتی از و مدرسه من برمیگشتیم دوستم
# 524 / 5040
# وقتی از و مدرسه دوستم من برمیگشتیم
# 525 / 5040
# وقتی از و مدرسه دوستم برمیگشتیم من
# 526 / 5040
# وقتی از و مدرسه برمیگشتیم من دوستم
# 527 / 5040
# وقتی از و مدرسه برمیگشتیم دوستم من
# 528 / 5040
# وقتی از دوستم من و برمیگشتیم مدرسه
# 529 / 5040
# وقتی از دوستم من و مدرسه برمیگشتیم
# 530 / 5040
# وقتی از دوستم من برمیگشتیم و مدرسه
# 531 / 5040
# وقتی از دوستم من برمیگشتیم مدرسه و
# 532 / 5040
# وقتی از دوستم من مدرسه و برمیگشتیم
# 533 / 5040
# وقتی از دوستم من مدرسه برمیگشتیم و
# 534 / 5040
# وقتی از دوستم و من برمیگشتیم مدرسه
# 535 / 5040
# وقتی از دوستم و من مدرسه برمیگشتیم
# 536 / 5040
# وقتی از دوستم و برمیگشتیم من مدرسه
# 537 / 5040
# وقتی از دوستم و برمیگشتیم مدرسه من
# 538 / 5040
# وقتی از دوستم و مدرسه من برمیگشتیم
# 539 / 5040
# وقتی از دوستم و مدرسه برمیگشتیم من
# 540 / 5040
# وقتی از دوستم برمیگشتیم من و مدرسه
# 541 / 5040
# وقتی از دوستم برمیگشتیم من مدرسه و
# 542 / 5040
# وقتی از دوستم برمیگشتیم و من مدرسه
# 543 / 5040
# وقتی از دوستم برمیگشتیم و مدرسه من
# 544 / 5040
# وقتی از دوستم برمیگشتیم مدرسه من و
# 545 / 5040
# وقتی از دوستم برمیگشتیم مدرسه و من
# 546 / 5040
# وقتی از دوستم مدرسه من و برمیگشتیم
# 547 / 5040
# وقتی از دوستم مدرسه من برمیگشتیم و
# 548 / 5040
# وقتی از دوستم مدرسه و من برمیگشتیم
# 549 / 5040
# وقتی از دوستم مدرسه و برمیگشتیم من
# 550 / 5040
# وقتی از دوستم مدرسه برمیگشتیم من و
# 551 / 5040
# وقتی از دوستم مدرسه برمیگشتیم و من
# 552 / 5040
# وقتی از برمیگشتیم من و دوستم مدرسه
# 553 / 5040
# وقتی از برمیگشتیم من و مدرسه دوستم
# 554 / 5040
# وقتی از برمیگشتیم من دوستم و مدرسه
# 555 / 5040
# وقتی از برمیگشتیم من دوستم مدرسه و
# 556 / 5040
# وقتی از برمیگشتیم من مدرسه و دوستم
# 557 / 5040
# وقتی از برمیگشتیم من مدرسه دوستم و
# 558 / 5040
# وقتی از برمیگشتیم و من دوستم مدرسه
# 559 / 5040
# وقتی از برمیگشتیم و من مدرسه دوستم
# 560 / 5040
# وقتی از برمیگشتیم و دوستم من مدرسه
# 561 / 5040
# وقتی از برمیگشتیم و دوستم مدرسه من
# 562 / 5040
# وقتی از برمیگشتیم و مدرسه من دوستم
# 563 / 5040
# وقتی از برمیگشتیم و مدرسه دوستم من
# 564 / 5040
# وقتی از برمیگشتیم دوستم من و مدرسه
# 565 / 5040
# وقتی از برمیگشتیم دوستم من مدرسه و
# 566 / 5040
# وقتی از برمیگشتیم دوستم و من مدرسه
# 567 / 5040
# وقتی از برمیگشتیم دوستم و مدرسه من
# 568 / 5040
# وقتی از برمیگشتیم دوستم مدرسه من و
# 569 / 5040
# وقتی از برمیگشتیم دوستم مدرسه و من
# 570 / 5040
# وقتی از برمیگشتیم مدرسه من و دوستم
# 571 / 5040
# وقتی از برمیگشتیم مدرسه من دوستم و
# 572 / 5040
# وقتی از برمیگشتیم مدرسه و من دوستم
# 573 / 5040
# وقتی از برمیگشتیم مدرسه و دوستم من
# 574 / 5040
# وقتی از برمیگشتیم مدرسه دوستم من و
# 575 / 5040
# وقتی از برمیگشتیم مدرسه دوستم و من
# 576 / 5040
# وقتی از مدرسه من و دوستم برمیگشتیم
# 577 / 5040
# وقتی از مدرسه من و برمیگشتیم دوستم
# 578 / 5040
# وقتی از مدرسه من دوستم و برمیگشتیم
# 579 / 5040
# وقتی از مدرسه من دوستم برمیگشتیم و
# 580 / 5040
# وقتی از مدرسه من برمیگشتیم و دوستم
# 581 / 5040
# وقتی از مدرسه من برمیگشتیم دوستم و
# 582 / 5040
# وقتی از مدرسه و من دوستم برمیگشتیم
# 583 / 5040
# وقتی از مدرسه و من برمیگشتیم دوستم
# 584 / 5040
# وقتی از مدرسه و دوستم من برمیگشتیم
# 585 / 5040
# وقتی از مدرسه و دوستم برمیگشتیم من
# 586 / 5040
# وقتی از مدرسه و برمیگشتیم من دوستم
# 587 / 5040
# وقتی از مدرسه و برمیگشتیم دوستم من
# 588 / 5040
# وقتی از مدرسه دوستم من و برمیگشتیم
# 589 / 5040
# وقتی از مدرسه دوستم من برمیگشتیم و
# 590 / 5040
# وقتی از مدرسه دوستم و من برمیگشتیم
# 591 / 5040
# وقتی از مدرسه دوستم و برمیگشتیم من
# 592 / 5040
# وقتی از مدرسه دوستم برمیگشتیم من و
# 593 / 5040
# وقتی از مدرسه دوستم برمیگشتیم و من
# 594 / 5040
# وقتی از مدرسه برمیگشتیم من و دوستم
# 595 / 5040
# وقتی از مدرسه برمیگشتیم من دوستم و
# 596 / 5040
# وقتی از مدرسه برمیگشتیم و من دوستم
# 597 / 5040
# وقتی از مدرسه برمیگشتیم و دوستم من
# 598 / 5040
# وقتی از مدرسه برمیگشتیم دوستم من و
# 599 / 5040
# وقتی از مدرسه برمیگشتیم دوستم و من
# 600 / 5040
# وقتی مدرسه من و دوستم برمیگشتیم از
# 601 / 5040
# وقتی مدرسه من و دوستم از برمیگشتیم
# 602 / 5040
# وقتی مدرسه من و برمیگشتیم دوستم از
# 603 / 5040
# وقتی مدرسه من و برمیگشتیم از دوستم
# 604 / 5040
# وقتی مدرسه من و از دوستم برمیگشتیم
# 605 / 5040
# وقتی مدرسه من و از برمیگشتیم دوستم
# 606 / 5040
# وقتی مدرسه من دوستم و برمیگشتیم از
# 607 / 5040
# وقتی مدرسه من دوستم و از برمیگشتیم
# 608 / 5040
# وقتی مدرسه من دوستم برمیگشتیم و از
# 609 / 5040
# وقتی مدرسه من دوستم برمیگشتیم از و
# 610 / 5040
# وقتی مدرسه من دوستم از و برمیگشتیم
# 611 / 5040
# وقتی مدرسه من دوستم از برمیگشتیم و
# 612 / 5040
# وقتی مدرسه من برمیگشتیم و دوستم از
# 613 / 5040
# وقتی مدرسه من برمیگشتیم و از دوستم
# 614 / 5040
# وقتی مدرسه من برمیگشتیم دوستم و از
# 615 / 5040
# وقتی مدرسه من برمیگشتیم دوستم از و
# 616 / 5040
# وقتی مدرسه من برمیگشتیم از و دوستم
# 617 / 5040
# وقتی مدرسه من برمیگشتیم از دوستم و
# 618 / 5040
# وقتی مدرسه من از و دوستم برمیگشتیم
# 619 / 5040
# وقتی مدرسه من از و برمیگشتیم دوستم
# 620 / 5040
# وقتی مدرسه من از دوستم و برمیگشتیم
# 621 / 5040
# وقتی مدرسه من از دوستم برمیگشتیم و
# 622 / 5040
# وقتی مدرسه من از برمیگشتیم و دوستم
# 623 / 5040
# وقتی مدرسه من از برمیگشتیم دوستم و
# 624 / 5040
# وقتی مدرسه و من دوستم برمیگشتیم از
# 625 / 5040
# وقتی مدرسه و من دوستم از برمیگشتیم
# 626 / 5040
# وقتی مدرسه و من برمیگشتیم دوستم از
# 627 / 5040
# وقتی مدرسه و من برمیگشتیم از دوستم
# 628 / 5040
# وقتی مدرسه و من از دوستم برمیگشتیم
# 629 / 5040
# وقتی مدرسه و من از برمیگشتیم دوستم
# 630 / 5040
# وقتی مدرسه و دوستم من برمیگشتیم از
# 631 / 5040
# وقتی مدرسه و دوستم من از برمیگشتیم
# 632 / 5040
# وقتی مدرسه و دوستم برمیگشتیم من از
# 633 / 5040
# وقتی مدرسه و دوستم برمیگشتیم از من
# 634 / 5040
# وقتی مدرسه و دوستم از من برمیگشتیم
# 635 / 5040
# وقتی مدرسه و دوستم از برمیگشتیم من
# 636 / 5040
# وقتی مدرسه و برمیگشتیم من دوستم از
# 637 / 5040
# وقتی مدرسه و برمیگشتیم من از دوستم
# 638 / 5040
# وقتی مدرسه و برمیگشتیم دوستم من از
# 639 / 5040
# وقتی مدرسه و برمیگشتیم دوستم از من
# 640 / 5040
# وقتی مدرسه و برمیگشتیم از من دوستم
# 641 / 5040
# وقتی مدرسه و برمیگشتیم از دوستم من
# 642 / 5040
# وقتی مدرسه و از من دوستم برمیگشتیم
# 643 / 5040
# وقتی مدرسه و از من برمیگشتیم دوستم
# 644 / 5040
# وقتی مدرسه و از دوستم من برمیگشتیم
# 645 / 5040
# وقتی مدرسه و از دوستم برمیگشتیم من
# 646 / 5040
# وقتی مدرسه و از برمیگشتیم من دوستم
# 647 / 5040
# وقتی مدرسه و از برمیگشتیم دوستم من
# 648 / 5040
# وقتی مدرسه دوستم من و برمیگشتیم از
# 649 / 5040
# وقتی مدرسه دوستم من و از برمیگشتیم
# 650 / 5040
# وقتی مدرسه دوستم من برمیگشتیم و از
# 651 / 5040
# وقتی مدرسه دوستم من برمیگشتیم از و
# 652 / 5040
# وقتی مدرسه دوستم من از و برمیگشتیم
# 653 / 5040
# وقتی مدرسه دوستم من از برمیگشتیم و
# 654 / 5040
# وقتی مدرسه دوستم و من برمیگشتیم از
# 655 / 5040
# وقتی مدرسه دوستم و من از برمیگشتیم
# 656 / 5040
# وقتی مدرسه دوستم و برمیگشتیم من از
# 657 / 5040
# وقتی مدرسه دوستم و برمیگشتیم از من
# 658 / 5040
# وقتی مدرسه دوستم و از من برمیگشتیم
# 659 / 5040
# وقتی مدرسه دوستم و از برمیگشتیم من
# 660 / 5040
# وقتی مدرسه دوستم برمیگشتیم من و از
# 661 / 5040
# وقتی مدرسه دوستم برمیگشتیم من از و
# 662 / 5040
# وقتی مدرسه دوستم برمیگشتیم و من از
# 663 / 5040
# وقتی مدرسه دوستم برمیگشتیم و از من
# 664 / 5040
# وقتی مدرسه دوستم برمیگشتیم از من و
# 665 / 5040
# وقتی مدرسه دوستم برمیگشتیم از و من
# 666 / 5040
# وقتی مدرسه دوستم از من و برمیگشتیم
# 667 / 5040
# وقتی مدرسه دوستم از من برمیگشتیم و
# 668 / 5040
# وقتی مدرسه دوستم از و من برمیگشتیم
# 669 / 5040
# وقتی مدرسه دوستم از و برمیگشتیم من
# 670 / 5040
# وقتی مدرسه دوستم از برمیگشتیم من و
# 671 / 5040
# وقتی مدرسه دوستم از برمیگشتیم و من
# 672 / 5040
# وقتی مدرسه برمیگشتیم من و دوستم از
# 673 / 5040
# وقتی مدرسه برمیگشتیم من و از دوستم
# 674 / 5040
# وقتی مدرسه برمیگشتیم من دوستم و از
# 675 / 5040
# وقتی مدرسه برمیگشتیم من دوستم از و
# 676 / 5040
# وقتی مدرسه برمیگشتیم من از و دوستم
# 677 / 5040
# وقتی مدرسه برمیگشتیم من از دوستم و
# 678 / 5040
# وقتی مدرسه برمیگشتیم و من دوستم از
# 679 / 5040
# وقتی مدرسه برمیگشتیم و من از دوستم
# 680 / 5040
# وقتی مدرسه برمیگشتیم و دوستم من از
# 681 / 5040
# وقتی مدرسه برمیگشتیم و دوستم از من
# 682 / 5040
# وقتی مدرسه برمیگشتیم و از من دوستم
# 683 / 5040
# وقتی مدرسه برمیگشتیم و از دوستم من
# 684 / 5040
# وقتی مدرسه برمیگشتیم دوستم من و از
# 685 / 5040
# وقتی مدرسه برمیگشتیم دوستم من از و
# 686 / 5040
# وقتی مدرسه برمیگشتیم دوستم و من از
# 687 / 5040
# وقتی مدرسه برمیگشتیم دوستم و از من
# 688 / 5040
# وقتی مدرسه برمیگشتیم دوستم از من و
# 689 / 5040
# وقتی مدرسه برمیگشتیم دوستم از و من
# 690 / 5040
# وقتی مدرسه برمیگشتیم از من و دوستم
# 691 / 5040
# وقتی مدرسه برمیگشتیم از من دوستم و
# 692 / 5040
# وقتی مدرسه برمیگشتیم از و من دوستم
# 693 / 5040
# وقتی مدرسه برمیگشتیم از و دوستم من
# 694 / 5040
# وقتی مدرسه برمیگشتیم از دوستم من و
# 695 / 5040
# وقتی مدرسه برمیگشتیم از دوستم و من
# 696 / 5040
# وقتی مدرسه از من و دوستم برمیگشتیم
# 697 / 5040
# وقتی مدرسه از من و برمیگشتیم دوستم
# 698 / 5040
# وقتی مدرسه از من دوستم و برمیگشتیم
# 699 / 5040
# وقتی مدرسه از من دوستم برمیگشتیم و
# 700 / 5040
# وقتی مدرسه از من برمیگشتیم و دوستم
# 701 / 5040
# وقتی مدرسه از من برمیگشتیم دوستم و
# 702 / 5040
# وقتی مدرسه از و من دوستم برمیگشتیم
# 703 / 5040
# وقتی مدرسه از و من برمیگشتیم دوستم
# 704 / 5040
# وقتی مدرسه از و دوستم من برمیگشتیم
# 705 / 5040
# وقتی مدرسه از و دوستم برمیگشتیم من
# 706 / 5040
# وقتی مدرسه از و برمیگشتیم من دوستم
# 707 / 5040
# وقتی مدرسه از و برمیگشتیم دوستم من
# 708 / 5040
# وقتی مدرسه از دوستم من و برمیگشتیم
# 709 / 5040
# وقتی مدرسه از دوستم من برمیگشتیم و
# 710 / 5040
# وقتی مدرسه از دوستم و من برمیگشتیم
# 711 / 5040
# وقتی مدرسه از دوستم و برمیگشتیم من
# 712 / 5040
# وقتی مدرسه از دوستم برمیگشتیم من و
# 713 / 5040
# وقتی مدرسه از دوستم برمیگشتیم و من
# 714 / 5040
# وقتی مدرسه از برمیگشتیم من و دوستم
# 715 / 5040
# وقتی مدرسه از برمیگشتیم من دوستم و
# 716 / 5040
# وقتی مدرسه از برمیگشتیم و من دوستم
# 717 / 5040
# وقتی مدرسه از برمیگشتیم و دوستم من
# 718 / 5040
# وقتی مدرسه از برمیگشتیم دوستم من و
# 719 / 5040
# وقتی مدرسه از برمیگشتیم دوستم و من
# 720 / 5040
# من وقتی و دوستم برمیگشتیم از مدرسه
# 721 / 5040
# من وقتی و دوستم برمیگشتیم مدرسه از
# 722 / 5040
# من وقتی و دوستم از برمیگشتیم مدرسه
# 723 / 5040
# من وقتی و دوستم از مدرسه برمیگشتیم
# 724 / 5040
# من وقتی و دوستم مدرسه برمیگشتیم از
# 725 / 5040
# من وقتی و دوستم مدرسه از برمیگشتیم
# 726 / 5040
# من وقتی و برمیگشتیم دوستم از مدرسه
# 727 / 5040
# من وقتی و برمیگشتیم دوستم مدرسه از
# 728 / 5040
# من وقتی و برمیگشتیم از دوستم مدرسه
# 729 / 5040
# من وقتی و برمیگشتیم از مدرسه دوستم
# 730 / 5040
# من وقتی و برمیگشتیم مدرسه دوستم از
# 731 / 5040
# من وقتی و برمیگشتیم مدرسه از دوستم
# 732 / 5040
# من وقتی و از دوستم برمیگشتیم مدرسه
# 733 / 5040
# من وقتی و از دوستم مدرسه برمیگشتیم
# 734 / 5040
# من وقتی و از برمیگشتیم دوستم مدرسه
# 735 / 5040
# من وقتی و از برمیگشتیم مدرسه دوستم
# 736 / 5040
# من وقتی و از مدرسه دوستم برمیگشتیم
# 737 / 5040
# من وقتی و از مدرسه برمیگشتیم دوستم
# 738 / 5040
# من وقتی و مدرسه دوستم برمیگشتیم از
# 739 / 5040
# من وقتی و مدرسه دوستم از برمیگشتیم
# 740 / 5040
# من وقتی و مدرسه برمیگشتیم دوستم از
# 741 / 5040
# من وقتی و مدرسه برمیگشتیم از دوستم
# 742 / 5040
# من وقتی و مدرسه از دوستم برمیگشتیم
# 743 / 5040
# من وقتی و مدرسه از برمیگشتیم دوستم
# 744 / 5040
# من وقتی دوستم و برمیگشتیم از مدرسه
# 745 / 5040
# من وقتی دوستم و برمیگشتیم مدرسه از
# 746 / 5040
# من وقتی دوستم و از برمیگشتیم مدرسه
# 747 / 5040
# من وقتی دوستم و از مدرسه برمیگشتیم
# 748 / 5040
# من وقتی دوستم و مدرسه برمیگشتیم از
# 749 / 5040
# من وقتی دوستم و مدرسه از برمیگشتیم
# 750 / 5040
# من وقتی دوستم برمیگشتیم و از مدرسه
# 751 / 5040
# من وقتی دوستم برمیگشتیم و مدرسه از
# 752 / 5040
# من وقتی دوستم برمیگشتیم از و مدرسه
# 753 / 5040
# من وقتی دوستم برمیگشتیم از مدرسه و
# 754 / 5040
# من وقتی دوستم برمیگشتیم مدرسه و از
# 755 / 5040
# من وقتی دوستم برمیگشتیم مدرسه از و
# 756 / 5040
# من وقتی دوستم از و برمیگشتیم مدرسه
# 757 / 5040
# من وقتی دوستم از و مدرسه برمیگشتیم
# 758 / 5040
# من وقتی دوستم از برمیگشتیم و مدرسه
# 759 / 5040
# من وقتی دوستم از برمیگشتیم مدرسه و
# 760 / 5040
# من وقتی دوستم از مدرسه و برمیگشتیم
# 761 / 5040
# من وقتی دوستم از مدرسه برمیگشتیم و
# 762 / 5040
# من وقتی دوستم مدرسه و برمیگشتیم از
# 763 / 5040
# من وقتی دوستم مدرسه و از برمیگشتیم
# 764 / 5040
# من وقتی دوستم مدرسه برمیگشتیم و از
# 765 / 5040
# من وقتی دوستم مدرسه برمیگشتیم از و
# 766 / 5040
# من وقتی دوستم مدرسه از و برمیگشتیم
# 767 / 5040
# من وقتی دوستم مدرسه از برمیگشتیم و
# 768 / 5040
# من وقتی برمیگشتیم و دوستم از مدرسه
# 769 / 5040
# من وقتی برمیگشتیم و دوستم مدرسه از
# 770 / 5040
# من وقتی برمیگشتیم و از دوستم مدرسه
# 771 / 5040
# من وقتی برمیگشتیم و از مدرسه دوستم
# 772 / 5040
# من وقتی برمیگشتیم و مدرسه دوستم از
# 773 / 5040
# من وقتی برمیگشتیم و مدرسه از دوستم
# 774 / 5040
# من وقتی برمیگشتیم دوستم و از مدرسه
# 775 / 5040
# من وقتی برمیگشتیم دوستم و مدرسه از
# 776 / 5040
# من وقتی برمیگشتیم دوستم از و مدرسه
# 777 / 5040
# من وقتی برمیگشتیم دوستم از مدرسه و
# 778 / 5040
# من وقتی برمیگشتیم دوستم مدرسه و از
# 779 / 5040
# من وقتی برمیگشتیم دوستم مدرسه از و
# 780 / 5040
# من وقتی برمیگشتیم از و دوستم مدرسه
# 781 / 5040
# من وقتی برمیگشتیم از و مدرسه دوستم
# 782 / 5040
# من وقتی برمیگشتیم از دوستم و مدرسه
# 783 / 5040
# من وقتی برمیگشتیم از دوستم مدرسه و
# 784 / 5040
# من وقتی برمیگشتیم از مدرسه و دوستم
# 785 / 5040
# من وقتی برمیگشتیم از مدرسه دوستم و
# 786 / 5040
# من وقتی برمیگشتیم مدرسه و دوستم از
# 787 / 5040
# من وقتی برمیگشتیم مدرسه و از دوستم
# 788 / 5040
# من وقتی برمیگشتیم مدرسه دوستم و از
# 789 / 5040
# من وقتی برمیگشتیم مدرسه دوستم از و
# 790 / 5040
# من وقتی برمیگشتیم مدرسه از و دوستم
# 791 / 5040
# من وقتی برمیگشتیم مدرسه از دوستم و
# 792 / 5040
# من وقتی از و دوستم برمیگشتیم مدرسه
# 793 / 5040
# من وقتی از و دوستم مدرسه برمیگشتیم
# 794 / 5040
# من وقتی از و برمیگشتیم دوستم مدرسه
# 795 / 5040
# من وقتی از و برمیگشتیم مدرسه دوستم
# 796 / 5040
# من وقتی از و مدرسه دوستم برمیگشتیم
# 797 / 5040
# من وقتی از و مدرسه برمیگشتیم دوستم
# 798 / 5040
# من وقتی از دوستم و برمیگشتیم مدرسه
# 799 / 5040
# من وقتی از دوستم و مدرسه برمیگشتیم
# 800 / 5040
# من وقتی از دوستم برمیگشتیم و مدرسه
# 801 / 5040
# من وقتی از دوستم برمیگشتیم مدرسه و
# 802 / 5040
# من وقتی از دوستم مدرسه و برمیگشتیم
# 803 / 5040
# من وقتی از دوستم مدرسه برمیگشتیم و
# 804 / 5040
# من وقتی از برمیگشتیم و دوستم مدرسه
# 805 / 5040
# من وقتی از برمیگشتیم و مدرسه دوستم
# 806 / 5040
# من وقتی از برمیگشتیم دوستم و مدرسه
# 807 / 5040
# من وقتی از برمیگشتیم دوستم مدرسه و
# 808 / 5040
# من وقتی از برمیگشتیم مدرسه و دوستم
# 809 / 5040
# من وقتی از برمیگشتیم مدرسه دوستم و
# 810 / 5040
# من وقتی از مدرسه و دوستم برمیگشتیم
# 811 / 5040
# من وقتی از مدرسه و برمیگشتیم دوستم
# 812 / 5040
# من وقتی از مدرسه دوستم و برمیگشتیم
# 813 / 5040
# من وقتی از مدرسه دوستم برمیگشتیم و
# 814 / 5040
# من وقتی از مدرسه برمیگشتیم و دوستم
# 815 / 5040
# من وقتی از مدرسه برمیگشتیم دوستم و
# 816 / 5040
# من وقتی مدرسه و دوستم برمیگشتیم از
# 817 / 5040
# من وقتی مدرسه و دوستم از برمیگشتیم
# 818 / 5040
# من وقتی مدرسه و برمیگشتیم دوستم از
# 819 / 5040
# من وقتی مدرسه و برمیگشتیم از دوستم
# 820 / 5040
# من وقتی مدرسه و از دوستم برمیگشتیم
# 821 / 5040
# من وقتی مدرسه و از برمیگشتیم دوستم
# 822 / 5040
# من وقتی مدرسه دوستم و برمیگشتیم از
# 823 / 5040
# من وقتی مدرسه دوستم و از برمیگشتیم
# 824 / 5040
# من وقتی مدرسه دوستم برمیگشتیم و از
# 825 / 5040
# من وقتی مدرسه دوستم برمیگشتیم از و
# 826 / 5040
# من وقتی مدرسه دوستم از و برمیگشتیم
# 827 / 5040
# من وقتی مدرسه دوستم از برمیگشتیم و
# 828 / 5040
# من وقتی مدرسه برمیگشتیم و دوستم از
# 829 / 5040
# من وقتی مدرسه برمیگشتیم و از دوستم
# 830 / 5040
# من وقتی مدرسه برمیگشتیم دوستم و از
# 831 / 5040
# من وقتی مدرسه برمیگشتیم دوستم از و
# 832 / 5040
# من وقتی مدرسه برمیگشتیم از و دوستم
# 833 / 5040
# من وقتی مدرسه برمیگشتیم از دوستم و
# 834 / 5040
# من وقتی مدرسه از و دوستم برمیگشتیم
# 835 / 5040
# من وقتی مدرسه از و برمیگشتیم دوستم
# 836 / 5040
# من وقتی مدرسه از دوستم و برمیگشتیم
# 837 / 5040
# من وقتی مدرسه از دوستم برمیگشتیم و
# 838 / 5040
# من وقتی مدرسه از برمیگشتیم و دوستم
# 839 / 5040
# من وقتی مدرسه از برمیگشتیم دوستم و
# 840 / 5040
# من و وقتی دوستم برمیگشتیم از مدرسه
# 841 / 5040
# من و وقتی دوستم برمیگشتیم مدرسه از
# 842 / 5040
# من و وقتی دوستم از برمیگشتیم مدرسه
# 843 / 5040
# من و وقتی دوستم از مدرسه برمیگشتیم
# 844 / 5040
# من و وقتی دوستم مدرسه برمیگشتیم از
# 845 / 5040
# من و وقتی دوستم مدرسه از برمیگشتیم
# 846 / 5040
# من و وقتی برمیگشتیم دوستم از مدرسه
# 847 / 5040
# من و وقتی برمیگشتیم دوستم مدرسه از
# 848 / 5040
# من و وقتی برمیگشتیم از دوستم مدرسه
# 849 / 5040
# من و وقتی برمیگشتیم از مدرسه دوستم
# 850 / 5040
# من و وقتی برمیگشتیم مدرسه دوستم از
# 851 / 5040
# من و وقتی برمیگشتیم مدرسه از دوستم
# 852 / 5040
# من و وقتی از دوستم برمیگشتیم مدرسه
# 853 / 5040
# من و وقتی از دوستم مدرسه برمیگشتیم
# 854 / 5040
# من و وقتی از برمیگشتیم دوستم مدرسه
# 855 / 5040
# من و وقتی از برمیگشتیم مدرسه دوستم
# 856 / 5040
# من و وقتی از مدرسه دوستم برمیگشتیم
# 857 / 5040
# من و وقتی از مدرسه برمیگشتیم دوستم
# 858 / 5040
# من و وقتی مدرسه دوستم برمیگشتیم از
# 859 / 5040
# من و وقتی مدرسه دوستم از برمیگشتیم
# 860 / 5040
# من و وقتی مدرسه برمیگشتیم دوستم از
# 861 / 5040
# من و وقتی مدرسه برمیگشتیم از دوستم
# 862 / 5040
# من و وقتی مدرسه از دوستم برمیگشتیم
# 863 / 5040
# من و وقتی مدرسه از برمیگشتیم دوستم
# 864 / 5040
# من و دوستم وقتی برمیگشتیم از مدرسه
# 865 / 5040
# من و دوستم وقتی برمیگشتیم مدرسه از
# 866 / 5040
# من و دوستم وقتی از برمیگشتیم مدرسه
# 867 / 5040
# من و دوستم وقتی از مدرسه برمیگشتیم
# 868 / 5040
# من و دوستم وقتی مدرسه برمیگشتیم از
# 869 / 5040
# من و دوستم وقتی مدرسه از برمیگشتیم
# 870 / 5040
# من و دوستم برمیگشتیم وقتی از مدرسه
# 871 / 5040
# من و دوستم برمیگشتیم وقتی مدرسه از
# 872 / 5040
# من و دوستم برمیگشتیم از وقتی مدرسه
# 873 / 5040
# من و دوستم برمیگشتیم از مدرسه وقتی
# 874 / 5040
# من و دوستم برمیگشتیم مدرسه وقتی از
# 875 / 5040
# من و دوستم برمیگشتیم مدرسه از وقتی
# 876 / 5040
# من و دوستم از وقتی برمیگشتیم مدرسه
# 877 / 5040
# من و دوستم از وقتی مدرسه برمیگشتیم
# 878 / 5040
# من و دوستم از برمیگشتیم وقتی مدرسه
# 879 / 5040
# من و دوستم از برمیگشتیم مدرسه وقتی
# 880 / 5040
# من و دوستم از مدرسه وقتی برمیگشتیم
# 881 / 5040
# من و دوستم از مدرسه برمیگشتیم وقتی
# 882 / 5040
# من و دوستم مدرسه وقتی برمیگشتیم از
# 883 / 5040
# من و دوستم مدرسه وقتی از برمیگشتیم
# 884 / 5040
# من و دوستم مدرسه برمیگشتیم وقتی از
# 885 / 5040
# من و دوستم مدرسه برمیگشتیم از وقتی
# 886 / 5040
# من و دوستم مدرسه از وقتی برمیگشتیم
# 887 / 5040
# من و دوستم مدرسه از برمیگشتیم وقتی
# 888 / 5040
# من و برمیگشتیم وقتی دوستم از مدرسه
# 889 / 5040
# من و برمیگشتیم وقتی دوستم مدرسه از
# 890 / 5040
# من و برمیگشتیم وقتی از دوستم مدرسه
# 891 / 5040
# من و برمیگشتیم وقتی از مدرسه دوستم
# 892 / 5040
# من و برمیگشتیم وقتی مدرسه دوستم از
# 893 / 5040
# من و برمیگشتیم وقتی مدرسه از دوستم
# 894 / 5040
# من و برمیگشتیم دوستم وقتی از مدرسه
# 895 / 5040
# من و برمیگشتیم دوستم وقتی مدرسه از
# 896 / 5040
# من و برمیگشتیم دوستم از وقتی مدرسه
# 897 / 5040
# من و برمیگشتیم دوستم از مدرسه وقتی
# 898 / 5040
# من و برمیگشتیم دوستم مدرسه وقتی از
# 899 / 5040
# من و برمیگشتیم دوستم مدرسه از وقتی
# 900 / 5040
# من و برمیگشتیم از وقتی دوستم مدرسه
# 901 / 5040
# من و برمیگشتیم از وقتی مدرسه دوستم
# 902 / 5040
# من و برمیگشتیم از دوستم وقتی مدرسه
# 903 / 5040
# من و برمیگشتیم از دوستم مدرسه وقتی
# 904 / 5040
# من و برمیگشتیم از مدرسه وقتی دوستم
# 905 / 5040
# من و برمیگشتیم از مدرسه دوستم وقتی
# 906 / 5040
# من و برمیگشتیم مدرسه وقتی دوستم از
# 907 / 5040
# من و برمیگشتیم مدرسه وقتی از دوستم
# 908 / 5040
# من و برمیگشتیم مدرسه دوستم وقتی از
# 909 / 5040
# من و برمیگشتیم مدرسه دوستم از وقتی
# 910 / 5040
# من و برمیگشتیم مدرسه از وقتی دوستم
# 911 / 5040
# من و برمیگشتیم مدرسه از دوستم وقتی
# 912 / 5040
# من و از وقتی دوستم برمیگشتیم مدرسه
# 913 / 5040
# من و از وقتی دوستم مدرسه برمیگشتیم
# 914 / 5040
# من و از وقتی برمیگشتیم دوستم مدرسه
# 915 / 5040
# من و از وقتی برمیگشتیم مدرسه دوستم
# 916 / 5040
# من و از وقتی مدرسه دوستم برمیگشتیم
# 917 / 5040
# من و از وقتی مدرسه برمیگشتیم دوستم
# 918 / 5040
# من و از دوستم وقتی برمیگشتیم مدرسه
# 919 / 5040
# من و از دوستم وقتی مدرسه برمیگشتیم
# 920 / 5040
# من و از دوستم برمیگشتیم وقتی مدرسه
# 921 / 5040
# من و از دوستم برمیگشتیم مدرسه وقتی
# 922 / 5040
# من و از دوستم مدرسه وقتی برمیگشتیم
# 923 / 5040
# من و از دوستم مدرسه برمیگشتیم وقتی
# 924 / 5040
# من و از برمیگشتیم وقتی دوستم مدرسه
# 925 / 5040
# من و از برمیگشتیم وقتی مدرسه دوستم
# 926 / 5040
# من و از برمیگشتیم دوستم وقتی مدرسه
# 927 / 5040
# من و از برمیگشتیم دوستم مدرسه وقتی
# 928 / 5040
# من و از برمیگشتیم مدرسه وقتی دوستم
# 929 / 5040
# من و از برمیگشتیم مدرسه دوستم وقتی
# 930 / 5040
# من و از مدرسه وقتی دوستم برمیگشتیم
# 931 / 5040
# من و از مدرسه وقتی برمیگشتیم دوستم
# 932 / 5040
# من و از مدرسه دوستم وقتی برمیگشتیم
# 933 / 5040
# من و از مدرسه دوستم برمیگشتیم وقتی
# 934 / 5040
# من و از مدرسه برمیگشتیم وقتی دوستم
# 935 / 5040
# من و از مدرسه برمیگشتیم دوستم وقتی
# 936 / 5040
# من و مدرسه وقتی دوستم برمیگشتیم از
# 937 / 5040
# من و مدرسه وقتی دوستم از برمیگشتیم
# 938 / 5040
# من و مدرسه وقتی برمیگشتیم دوستم از
# 939 / 5040
# من و مدرسه وقتی برمیگشتیم از دوستم
# 940 / 5040
# من و مدرسه وقتی از دوستم برمیگشتیم
# 941 / 5040
# من و مدرسه وقتی از برمیگشتیم دوستم
# 942 / 5040
# من و مدرسه دوستم وقتی برمیگشتیم از
# 943 / 5040
# من و مدرسه دوستم وقتی از برمیگشتیم
# 944 / 5040
# من و مدرسه دوستم برمیگشتیم وقتی از
# 945 / 5040
# من و مدرسه دوستم برمیگشتیم از وقتی
# 946 / 5040
# من و مدرسه دوستم از وقتی برمیگشتیم
# 947 / 5040
# من و مدرسه دوستم از برمیگشتیم وقتی
# 948 / 5040
# من و مدرسه برمیگشتیم وقتی دوستم از
# 949 / 5040
# من و مدرسه برمیگشتیم وقتی از دوستم
# 950 / 5040
# من و مدرسه برمیگشتیم دوستم وقتی از
# 951 / 5040
# من و مدرسه برمیگشتیم دوستم از وقتی
# 952 / 5040
# من و مدرسه برمیگشتیم از وقتی دوستم
# 953 / 5040
# من و مدرسه برمیگشتیم از دوستم وقتی
# 954 / 5040
# من و مدرسه از وقتی دوستم برمیگشتیم
# 955 / 5040
# من و مدرسه از وقتی برمیگشتیم دوستم
# 956 / 5040
# من و مدرسه از دوستم وقتی برمیگشتیم
# 957 / 5040
# من و مدرسه از دوستم برمیگشتیم وقتی
# 958 / 5040
# من و مدرسه از برمیگشتیم وقتی دوستم
# 959 / 5040
# من و مدرسه از برمیگشتیم دوستم وقتی
# 960 / 5040
# من دوستم وقتی و برمیگشتیم از مدرسه
# 961 / 5040
# من دوستم وقتی و برمیگشتیم مدرسه از
# 962 / 5040
# من دوستم وقتی و از برمیگشتیم مدرسه
# 963 / 5040
# من دوستم وقتی و از مدرسه برمیگشتیم
# 964 / 5040
# من دوستم وقتی و مدرسه برمیگشتیم از
# 965 / 5040
# من دوستم وقتی و مدرسه از برمیگشتیم
# 966 / 5040
# من دوستم وقتی برمیگشتیم و از مدرسه
# 967 / 5040
# من دوستم وقتی برمیگشتیم و مدرسه از
# 968 / 5040
# من دوستم وقتی برمیگشتیم از و مدرسه
# 969 / 5040
# من دوستم وقتی برمیگشتیم از مدرسه و
# 970 / 5040
# من دوستم وقتی برمیگشتیم مدرسه و از
# 971 / 5040
# من دوستم وقتی برمیگشتیم مدرسه از و
# 972 / 5040
# من دوستم وقتی از و برمیگشتیم مدرسه
# 973 / 5040
# من دوستم وقتی از و مدرسه برمیگشتیم
# 974 / 5040
# من دوستم وقتی از برمیگشتیم و مدرسه
# 975 / 5040
# من دوستم وقتی از برمیگشتیم مدرسه و
# 976 / 5040
# من دوستم وقتی از مدرسه و برمیگشتیم
# 977 / 5040
# من دوستم وقتی از مدرسه برمیگشتیم و
# 978 / 5040
# من دوستم وقتی مدرسه و برمیگشتیم از
# 979 / 5040
# من دوستم وقتی مدرسه و از برمیگشتیم
# 980 / 5040
# من دوستم وقتی مدرسه برمیگشتیم و از
# 981 / 5040
# من دوستم وقتی مدرسه برمیگشتیم از و
# 982 / 5040
# من دوستم وقتی مدرسه از و برمیگشتیم
# 983 / 5040
# من دوستم وقتی مدرسه از برمیگشتیم و
# 984 / 5040
# من دوستم و وقتی برمیگشتیم از مدرسه
# 985 / 5040
# من دوستم و وقتی برمیگشتیم مدرسه از
# 986 / 5040
# من دوستم و وقتی از برمیگشتیم مدرسه
# 987 / 5040
# من دوستم و وقتی از مدرسه برمیگشتیم
# 988 / 5040
# من دوستم و وقتی مدرسه برمیگشتیم از
# 989 / 5040
# من دوستم و وقتی مدرسه از برمیگشتیم
# 990 / 5040
# من دوستم و برمیگشتیم وقتی از مدرسه
# 991 / 5040
# من دوستم و برمیگشتیم وقتی مدرسه از
# 992 / 5040
# من دوستم و برمیگشتیم از وقتی مدرسه
# 993 / 5040
# من دوستم و برمیگشتیم از مدرسه وقتی
# 994 / 5040
# من دوستم و برمیگشتیم مدرسه وقتی از
# 995 / 5040
# من دوستم و برمیگشتیم مدرسه از وقتی
# 996 / 5040
# من دوستم و از وقتی برمیگشتیم مدرسه
# 997 / 5040
# من دوستم و از وقتی مدرسه برمیگشتیم
# 998 / 5040
# من دوستم و از برمیگشتیم وقتی مدرسه
# 999 / 5040
# من دوستم و از برمیگشتیم مدرسه وقتی
# 1000 / 5040
# من دوستم و از مدرسه وقتی برمیگشتیم
# 1001 / 5040
# من دوستم و از مدرسه برمیگشتیم وقتی
# 1002 / 5040
# من دوستم و مدرسه وقتی برمیگشتیم از
# 1003 / 5040
# من دوستم و مدرسه وقتی از برمیگشتیم
# 1004 / 5040
# من دوستم و مدرسه برمیگشتیم وقتی از
# 1005 / 5040
# من دوستم و مدرسه برمیگشتیم از وقتی
# 1006 / 5040
# من دوستم و مدرسه از وقتی برمیگشتیم
# 1007 / 5040
# من دوستم و مدرسه از برمیگشتیم وقتی
# 1008 / 5040
# من دوستم برمیگشتیم وقتی و از مدرسه
# 1009 / 5040
# من دوستم برمیگشتیم وقتی و مدرسه از
# 1010 / 5040
# من دوستم برمیگشتیم وقتی از و مدرسه
# 1011 / 5040
# من دوستم برمیگشتیم وقتی از مدرسه و
# 1012 / 5040
# من دوستم برمیگشتیم وقتی مدرسه و از
# 1013 / 5040
# من دوستم برمیگشتیم وقتی مدرسه از و
# 1014 / 5040
# من دوستم برمیگشتیم و وقتی از مدرسه
# 1015 / 5040
# من دوستم برمیگشتیم و وقتی مدرسه از
# 1016 / 5040
# من دوستم برمیگشتیم و از وقتی مدرسه
# 1017 / 5040
# من دوستم برمیگشتیم و از مدرسه وقتی
# 1018 / 5040
# من دوستم برمیگشتیم و مدرسه وقتی از
# 1019 / 5040
# من دوستم برمیگشتیم و مدرسه از وقتی
# 1020 / 5040
# من دوستم برمیگشتیم از وقتی و مدرسه
# 1021 / 5040
# من دوستم برمیگشتیم از وقتی مدرسه و
# 1022 / 5040
# من دوستم برمیگشتیم از و وقتی مدرسه
# 1023 / 5040
# من دوستم برمیگشتیم از و مدرسه وقتی
# 1024 / 5040
# من دوستم برمیگشتیم از مدرسه وقتی و
# 1025 / 5040
# من دوستم برمیگشتیم از مدرسه و وقتی
# 1026 / 5040
# من دوستم برمیگشتیم مدرسه وقتی و از
# 1027 / 5040
# من دوستم برمیگشتیم مدرسه وقتی از و
# 1028 / 5040
# من دوستم برمیگشتیم مدرسه و وقتی از
# 1029 / 5040
# من دوستم برمیگشتیم مدرسه و از وقتی
# 1030 / 5040
# من دوستم برمیگشتیم مدرسه از وقتی و
# 1031 / 5040
# من دوستم برمیگشتیم مدرسه از و وقتی
# 1032 / 5040
# من دوستم از وقتی و برمیگشتیم مدرسه
# 1033 / 5040
# من دوستم از وقتی و مدرسه برمیگشتیم
# 1034 / 5040
# من دوستم از وقتی برمیگشتیم و مدرسه
# 1035 / 5040
# من دوستم از وقتی برمیگشتیم مدرسه و
# 1036 / 5040
# من دوستم از وقتی مدرسه و برمیگشتیم
# 1037 / 5040
# من دوستم از وقتی مدرسه برمیگشتیم و
# 1038 / 5040
# من دوستم از و وقتی برمیگشتیم مدرسه
# 1039 / 5040
# من دوستم از و وقتی مدرسه برمیگشتیم
# 1040 / 5040
# من دوستم از و برمیگشتیم وقتی مدرسه
# 1041 / 5040
# من دوستم از و برمیگشتیم مدرسه وقتی
# 1042 / 5040
# من دوستم از و مدرسه وقتی برمیگشتیم
# 1043 / 5040
# من دوستم از و مدرسه برمیگشتیم وقتی
# 1044 / 5040
# من دوستم از برمیگشتیم وقتی و مدرسه
# ...
# و من مدرسه برمیگشتیم وقتی دوستم از
# 1669 / 5040
# و من مدرسه برمیگشتیم وقتی از دوستم
# 1670 / 5040
# و من مدرسه برمیگشتیم دوستم وقتی از
# 1671 / 5040
# و من مدرسه برمیگشتیم دوستم از وقتی
# 1672 / 5040
# و من مدرسه برمیگشتیم از وقتی دوستم
# 1673 / 5040
# و من مدرسه برمیگشتیم از دوستم وقتی
# 1674 / 5040
# و من مدرسه از وقتی دوستم برمیگشتیم
# 1675 / 5040
# و من مدرسه از وقتی برمیگشتیم دوستم
# 1676 / 5040
# و من مدرسه از دوستم وقتی برمیگشتیم
# 1677 / 5040
# و من مدرسه از دوستم برمیگشتیم وقتی
# 1678 / 5040
# و من مدرسه از برمیگشتیم وقتی دوستم
# 1679 / 5040
# و من مدرسه از برمیگشتیم دوستم وقتی
# 1680 / 5040
# و دوستم وقتی من برمیگشتیم از مدرسه
# 1681 / 5040
# و دوستم وقتی من برمیگشتیم مدرسه از
# 1682 / 5040
# و دوستم وقتی من از برمیگشتیم مدرسه
# 1683 / 5040
# و دوستم وقتی من از مدرسه برمیگشتیم
# 1684 / 5040
# و دوستم وقتی من مدرسه برمیگشتیم از
# 1685 / 5040
# و دوستم وقتی من مدرسه از برمیگشتیم
# 1686 / 5040
# و دوستم وقتی برمیگشتیم من از مدرسه
# 1687 / 5040
# و دوستم وقتی برمیگشتیم من مدرسه از
# 1688 / 5040
# و دوستم وقتی برمیگشتیم از من مدرسه
# 1689 / 5040
# و دوستم وقتی برمیگشتیم از مدرسه من
# 1690 / 5040
# و دوستم وقتی برمیگشتیم مدرسه من از
# 1691 / 5040
# و دوستم وقتی برمیگشتیم مدرسه از من
# 1692 / 5040
# و دوستم وقتی از من برمیگشتیم مدرسه
# 1693 / 5040
# و دوستم وقتی از من مدرسه برمیگشتیم
# 1694 / 5040
# و دوستم وقتی از برمیگشتیم من مدرسه
# 1695 / 5040
# و دوستم وقتی از برمیگشتیم مدرسه من
# 1696 / 5040
# و دوستم وقتی از مدرسه من برمیگشتیم
# 1697 / 5040
# و دوستم وقتی از مدرسه برمیگشتیم من
# 1698 / 5040
# و دوستم وقتی مدرسه من برمیگشتیم از
# 1699 / 5040
# و دوستم وقتی مدرسه من از برمیگشتیم
# 1700 / 5040
# و دوستم وقتی مدرسه برمیگشتیم من از
# 1701 / 5040
# و دوستم وقتی مدرسه برمیگشتیم از من
# 1702 / 5040
# و دوستم وقتی مدرسه از من برمیگشتیم
# 1703 / 5040
# و دوستم وقتی مدرسه از برمیگشتیم من
# 1704 / 5040
# و دوستم من وقتی برمیگشتیم از مدرسه
# 1705 / 5040
# و دوستم من وقتی برمیگشتیم مدرسه از
# 1706 / 5040
# و دوستم من وقتی از برمیگشتیم مدرسه
# 1707 / 5040
# و دوستم من وقتی از مدرسه برمیگشتیم
# 1708 / 5040
# و دوستم من وقتی مدرسه برمیگشتیم از
# 1709 / 5040
# و دوستم من وقتی مدرسه از برمیگشتیم
# 1710 / 5040
# و دوستم من برمیگشتیم وقتی از مدرسه
# 1711 / 5040
# و دوستم من برمیگشتیم وقتی مدرسه از
# 1712 / 5040
# و دوستم من برمیگشتیم از وقتی مدرسه
# 1713 / 5040
# و دوستم من برمیگشتیم از مدرسه وقتی
# 1714 / 5040
# و دوستم من برمیگشتیم مدرسه وقتی از
# 1715 / 5040
# و دوستم من برمیگشتیم مدرسه از وقتی
# 1716 / 5040
# و دوستم من از وقتی برمیگشتیم مدرسه
# 1717 / 5040
# و دوستم من از وقتی مدرسه برمیگشتیم
# 1718 / 5040
# و دوستم من از برمیگشتیم وقتی مدرسه
# 1719 / 5040
# و دوستم من از برمیگشتیم مدرسه وقتی
# 1720 / 5040
# و دوستم من از مدرسه وقتی برمیگشتیم
# 1721 / 5040
# و دوستم من از مدرسه برمیگشتیم وقتی
# 1722 / 5040
# و دوستم من مدرسه وقتی برمیگشتیم از
# 1723 / 5040
# و دوستم من مدرسه وقتی از برمیگشتیم
# 1724 / 5040
# و دوستم من مدرسه برمیگشتیم وقتی از
# 1725 / 5040
# و دوستم من مدرسه برمیگشتیم از وقتی
# 1726 / 5040
# و دوستم من مدرسه از وقتی برمیگشتیم
# 1727 / 5040
# و دوستم من مدرسه از برمیگشتیم وقتی
# 1728 / 5040
# و دوستم برمیگشتیم وقتی من از مدرسه
# 1729 / 5040
# و دوستم برمیگشتیم وقتی من مدرسه از
# 1730 / 5040
# و دوستم برمیگشتیم وقتی از من مدرسه
# 1731 / 5040
# و دوستم برمیگشتیم وقتی از مدرسه من
# 1732 / 5040
# و دوستم برمیگشتیم وقتی مدرسه من از
# 1733 / 5040
# و دوستم برمیگشتیم وقتی مدرسه از من
# 1734 / 5040
# و دوستم برمیگشتیم من وقتی از مدرسه
# 1735 / 5040
# و دوستم برمیگشتیم من وقتی مدرسه از
# 1736 / 5040
# و دوستم برمیگشتیم من از وقتی مدرسه
# 1737 / 5040
# و دوستم برمیگشتیم من از مدرسه وقتی
# 1738 / 5040
# و دوستم برمیگشتیم من مدرسه وقتی از
# 1739 / 5040
# و دوستم برمیگشتیم من مدرسه از وقتی
# 1740 / 5040
# و دوستم برمیگشتیم از وقتی من مدرسه
# 1741 / 5040
# و دوستم برمیگشتیم از وقتی مدرسه من
# 1742 / 5040
# و دوستم برمیگشتیم از من وقتی مدرسه
# 1743 / 5040
# و دوستم برمیگشتیم از من مدرسه وقتی
# 1744 / 5040
# و دوستم برمیگشتیم از مدرسه وقتی من
# 1745 / 5040
# و دوستم برمیگشتیم از مدرسه من وقتی
# 1746 / 5040
# و دوستم برمیگشتیم مدرسه وقتی من از
# 1747 / 5040
# و دوستم برمیگشتیم مدرسه وقتی از من
# 1748 / 5040
# و دوستم برمیگشتیم مدرسه من وقتی از
# 1749 / 5040
# و دوستم برمیگشتیم مدرسه من از وقتی
# 1750 / 5040
# و دوستم برمیگشتیم مدرسه از وقتی من
# 1751 / 5040
# و دوستم برمیگشتیم مدرسه از من وقتی
# 1752 / 5040
# و دوستم از وقتی من برمیگشتیم مدرسه
# 1753 / 5040
# و دوستم از وقتی من مدرسه برمیگشتیم
# 1754 / 5040
# و دوستم از وقتی برمیگشتیم من مدرسه
# 1755 / 5040
# و دوستم از وقتی برمیگشتیم مدرسه من
# 1756 / 5040
# و دوستم از وقتی مدرسه من برمیگشتیم
# 1757 / 5040
# و دوستم از وقتی مدرسه برمیگشتیم من
# 1758 / 5040
# و دوستم از من وقتی برمیگشتیم مدرسه
# 1759 / 5040
# و دوستم از من وقتی مدرسه برمیگشتیم
# 1760 / 5040
# و دوستم از من برمیگشتیم وقتی مدرسه
# 1761 / 5040
# و دوستم از من برمیگشتیم مدرسه وقتی
# 1762 / 5040
# و دوستم از من مدرسه وقتی برمیگشتیم
# 1763 / 5040
# و دوستم از من مدرسه برمیگشتیم وقتی
# 1764 / 5040
# و دوستم از برمیگشتیم وقتی من مدرسه
# 1765 / 5040
# و دوستم از برمیگشتیم وقتی مدرسه من
# 1766 / 5040
# و دوستم از برمیگشتیم من وقتی مدرسه
# 1767 / 5040
# و دوستم از برمیگشتیم من مدرسه وقتی
# 1768 / 5040
# و دوستم از برمیگشتیم مدرسه وقتی من
# 1769 / 5040
# و دوستم از برمیگشتیم مدرسه من وقتی
# 1770 / 5040
# و دوستم از مدرسه وقتی من برمیگشتیم
# 1771 / 5040
# و دوستم از مدرسه وقتی برمیگشتیم من
# 1772 / 5040
# و دوستم از مدرسه من وقتی برمیگشتیم
# 1773 / 5040
# و دوستم از مدرسه من برمیگشتیم وقتی
# 1774 / 5040
# و دوستم از مدرسه برمیگشتیم وقتی من
# 1775 / 5040
# و دوستم از مدرسه برمیگشتیم من وقتی
# 1776 / 5040
# و دوستم مدرسه وقتی من برمیگشتیم از
# 1777 / 5040
# و دوستم مدرسه وقتی من از برمیگشتیم
# 1778 / 5040
# و دوستم مدرسه وقتی برمیگشتیم من از
# 1779 / 5040
# و دوستم مدرسه وقتی برمیگشتیم از من
# 1780 / 5040
# و دوستم مدرسه وقتی از من برمیگشتیم
# 1781 / 5040
# و دوستم مدرسه وقتی از برمیگشتیم من
# 1782 / 5040
# و دوستم مدرسه من وقتی برمیگشتیم از
# 1783 / 5040
# و دوستم مدرسه من وقتی از برمیگشتیم
# 1784 / 5040
# و دوستم مدرسه من برمیگشتیم وقتی از
# 1785 / 5040
# و دوستم مدرسه من برمیگشتیم از وقتی
# 1786 / 5040
# و دوستم مدرسه من از وقتی برمیگشتیم
# 1787 / 5040
# و دوستم مدرسه من از برمیگشتیم وقتی
# 1788 / 5040
# و دوستم مدرسه برمیگشتیم وقتی من از
# 1789 / 5040
# و دوستم مدرسه برمیگشتیم وقتی از من
# 1790 / 5040
# و دوستم مدرسه برمیگشتیم من وقتی از
# 1791 / 5040
# و دوستم مدرسه برمیگشتیم من از وقتی
# 1792 / 5040
# و دوستم مدرسه برمیگشتیم از وقتی من
# 1793 / 5040
# و دوستم مدرسه برمیگشتیم از من وقتی
# 1794 / 5040
# و دوستم مدرسه از وقتی من برمیگشتیم
# 1795 / 5040
# و دوستم مدرسه از وقتی برمیگشتیم من
# 1796 / 5040
# و دوستم مدرسه از من وقتی برمیگشتیم
# 1797 / 5040
# و دوستم مدرسه از من برمیگشتیم وقتی
# 1798 / 5040
# و دوستم مدرسه از برمیگشتیم وقتی من
# 1799 / 5040
# و دوستم مدرسه از برمیگشتیم من وقتی
# 1800 / 5040
# و برمیگشتیم وقتی من دوستم از مدرسه
# 1801 / 5040
# و برمیگشتیم وقتی من دوستم مدرسه از
# 1802 / 5040
# و برمیگشتیم وقتی من از دوستم مدرسه
# 1803 / 5040
# و برمیگشتیم وقتی من از مدرسه دوستم
# 1804 / 5040
# و برمیگشتیم وقتی من مدرسه دوستم از
# 1805 / 5040
# و برمیگشتیم وقتی من مدرسه از دوستم
# 1806 / 5040
# و برمیگشتیم وقتی دوستم من از مدرسه
# 1807 / 5040
# و برمیگشتیم وقتی دوستم من مدرسه از
# 1808 / 5040
# و برمیگشتیم وقتی دوستم از من مدرسه
# 1809 / 5040
# و برمیگشتیم وقتی دوستم از مدرسه من
# 1810 / 5040
# و برمیگشتیم وقتی دوستم مدرسه من از
# 1811 / 5040
# و برمیگشتیم وقتی دوستم مدرسه از من
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 53
#      51 for i,permutation in enumerate(permutations):
#      52     print(' '.join(permutation))
# ---> 53     scores.append((' '.join(permutation),calculate_sentence_score(list(permutation))))
#      54     print(i+1,'/',len(permutations))
#      55 scores.sort(key=lambda x: x[1], reverse=True)
#
# Cell In[7], line 9, in calculate_sentence_score(sentence_tokens)
#       6 masked_text = ' '.join(tokens[:i])+' [MASK] '+' '.join(tokens[i+1:])
#       8 inputs = tokenizer(masked_text, return_tensors="tf")
# ----> 9 outputs = model(inputs)
#      10 logits = outputs.logits
#      12 mask_token_index = tf.where(inputs["input_ids"] == tokenizer.mask_token_id)[0, 1]
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\training.py:558, in Model.__call__(self, *args, **kwargs)
#     554         super().__call__(inputs, *copied_args, **copied_kwargs)
#     556     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 558 return super().__call__(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\transformers\modeling_tf_utils.py:434, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     431     config = self.config
#     433 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
# --> 434 return func(self, **unpacked_inputs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\transformers\models\bert\modeling_tf_bert.py:1347, in TFBertForMaskedLM.call(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, labels, training)
#    1334 outputs = self.bert(
#    1335     input_ids=input_ids,
#    1336     attention_mask=attention_mask,
#    (...)
#    1344     training=training,
#    1345 )
#    1346 sequence_output = outputs[0]
# -> 1347 prediction_scores = self.mlm(sequence_output=sequence_output, training=training)
#    1348 loss = None if labels is None else self.hf_compute_loss(labels=labels, logits=prediction_scores)
#    1350 if not return_dict:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\transformers\models\bert\modeling_tf_bert.py:695, in TFBertMLMHead.call(self, sequence_output)
#     694 def call(self, sequence_output: tf.Tensor) -> tf.Tensor:
# --> 695     prediction_scores = self.predictions(hidden_states=sequence_output)
#     697     return prediction_scores
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\transformers\models\bert\modeling_tf_bert.py:681, in TFBertLMPredictionHead.call(self, hidden_states)
#     679 seq_length = shape_list(hidden_states)[1]
#     680 hidden_states = tf.reshape(tensor=hidden_states, shape=[-1, self.hidden_size])
# --> 681 hidden_states = tf.matmul(a=hidden_states, b=self.input_embeddings.weight, transpose_b=True)
#     682 hidden_states = tf.reshape(tensor=hidden_states, shape=[-1, seq_length, self.config.vocab_size])
#     683 hidden_states = tf.nn.bias_add(value=hidden_states, bias=self.bias)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\ops\math_ops.py:3766, in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3763   return gen_math_ops.batch_mat_mul_v3(
#    3764       a, b, adj_x=adjoint_a, adj_y=adjoint_b, Tout=output_type, name=name)
#    3765 else:
# -> 3766   return gen_math_ops.mat_mul(
#    3767       a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:6713, in mat_mul(a, b, transpose_a, transpose_b, name)
#    6711 if tld.is_eager:
#    6712   try:
# -> 6713     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6714       _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
#    6715       transpose_b)
#    6716     return _result
#    6717   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
